# %% [markdown]
# ### Example 2 - Book Data: Compute Average Daily Spread
#
# In this example, we're going to compute the average daily spread for Tritanium at Jita IV - Moon 4 - Caldari Navy Assembly Plant in The Forge.  The average daily spread is the average of the spread computed for each of the 288 snapshots which make up a day of order book data \(5 minute snapshots, 12 per hour, 288 per day\).  As with Example 1, we'll first show how to compute spread from first principles, then we'll introduce libraries which make the process easier.

# %%
# Standard imports
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline
# EveKit imports
from evekit.reference import Client
from evekit.util import convert_raw_time

# %%
# Settings for the day we want to compute
# We retreive type, region and station ID from the SDE
sde_client = Client.SDE.get()
type_query = "{values: ['Tritanium']}"
region_query = "{values: ['The Forge']}"
station_query = "{values: ['Jita IV - Moon 4 - Caldari Navy Assembly Plant']}"
type_id = sde_client.Inventory.getTypes(typeName=type_query).result()[0][0]['typeID']
region_id = sde_client.Map.getRegions(regionName=region_query).result()[0][0]['regionID']
station_id = sde_client.Station.getStations(stationName=station_query).result()[0][0]['stationID']
compute_date = convert_raw_time(1483228800000) # 2017-01-01 12:00 AM UTC
print("Using type_id=%d, region_id=%d, station_id=%d at %s" % (type_id, region_id, station_id, str(compute_date)))
# Out:
# Using type_id=34, region_id=10000002, station_id=60003760 at 2017-01-01 00:00:00

# %%
# Let's develop code for computing spread from an order book retrieved from the Orbital Enterprises market data service
# 
# To start, we'll need the client for the service.  We'll also fetch the first book available on our compute date.
mdc_client = Client.MarketData.get()
sample_book = mdc_client.MarketData.book(typeID=type_id, regionID=region_id, date=str(compute_date) + " UTC").result()[0]
sample_book
# Out:
# {'bookTime': 1483228800000,
#  'orders': [{'buy': True,
#    'duration': 90,
#    'issued': 1481705362000,
#    'locationID': 60002242,
#    'minVolume': 1,
#    'orderID': 4708935394,
#    'orderRange': 'solarsystem',
#    'price': 5,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 43758803,
#    'volumeEntered': 200000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1483056665000,
#    'locationID': 60001591,
#    'minVolume': 1,
#    'orderID': 4719143619,
#    'orderRange': 'station',
#    'price': 4.86,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 13303703,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 30,
#    'issued': 1483014155000,
#    'locationID': 60001594,
#    'minVolume': 1,
#    'orderID': 4731076447,
#    'orderRange': 'station',
#    'price': 4.85,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 13381581,
#    'volumeEntered': 20000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1483020345000,
#    'locationID': 60002818,
#    'minVolume': 1,
#    'orderID': 4731159119,
#    'orderRange': 'station',
#    'price': 4.83,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 9718405,
#    'volumeEntered': 30000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1483023984000,
#    'locationID': 60010819,
#    'minVolume': 1,
#    'orderID': 4731212373,
#    'orderRange': 'station',
#    'price': 4.81,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 996935,
#    'volumeEntered': 1000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1483204836000,
#    'locationID': 60004051,
#    'minVolume': 1,
#    'orderID': 4733726383,
#    'orderRange': '3',
#    'price': 4.75,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 4900182,
#    'volumeEntered': 5000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1483033648000,
#    'locationID': 60003211,
#    'minVolume': 1000,
#    'orderID': 4731376068,
#    'orderRange': '2',
#    'price': 4.7,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 776638,
#    'volumeEntered': 5000000},
#   {'buy': True,
#    'duration': 30,
#    'issued': 1481599466000,
#    'locationID': 60003055,
#    'minVolume': 1,
#    'orderID': 4711604426,
#    'orderRange': 'station',
#    'price': 4.67,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 5000000,
#    'volumeEntered': 5000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1483207240000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4733760768,
#    'orderRange': '1',
#    'price': 4.66,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1702478781,
#    'volumeEntered': 2000000000},
#   {'buy': True,
#    'duration': 30,
#    'issued': 1480877019000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4701276671,
#    'orderRange': 'station',
#    'price': 4.65,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 78774738,
#    'volumeEntered': 200000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1482622428000,
#    'locationID': 1021705628874,
#    'minVolume': 1,
#    'orderID': 4726038430,
#    'orderRange': '1',
#    'price': 4.63,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 27605009,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1480751724000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4699131616,
#    'orderRange': 'station',
#    'price': 4.62,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 100000000,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 7,
#    'issued': 1483099737000,
#    'locationID': 60010195,
#    'minVolume': 1,
#    'orderID': 4732257219,
#    'orderRange': 'solarsystem',
#    'price': 4.61,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 8642416,
#    'volumeEntered': 10000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1480872129000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4701158083,
#    'orderRange': 'station',
#    'price': 4.6,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 100000000,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 3,
#    'issued': 1482981181000,
#    'locationID': 60002359,
#    'minVolume': 1,
#    'orderID': 4730740860,
#    'orderRange': 'station',
#    'price': 4.52,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 80000,
#    'volumeEntered': 80000},
#   {'buy': True,
#    'duration': 30,
#    'issued': 1482087899000,
#    'locationID': 60002359,
#    'minVolume': 1,
#    'orderID': 4714691792,
#    'orderRange': 'station',
#    'price': 4.51,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 5326094,
#    'volumeEntered': 8000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1480784461000,
#    'locationID': 60002290,
#    'minVolume': 1,
#    'orderID': 4641995905,
#    'orderRange': 'station',
#    'price': 4.5,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 83947801,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1482378565000,
#    'locationID': 60002749,
#    'minVolume': 1,
#    'orderID': 4722740618,
#    'orderRange': 'solarsystem',
#    'price': 4.49,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 29010498,
#    'volumeEntered': 30000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1482570018000,
#    'locationID': 60010195,
#    'minVolume': 1,
#    'orderID': 4710737688,
#    'orderRange': 'station',
#    'price': 4.4,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 6199571,
#    'volumeEntered': 50000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1483203467000,
#    'locationID': 60014659,
#    'minVolume': 1,
#    'orderID': 4733705222,
#    'orderRange': 'solarsystem',
#    'price': 4.26,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 910122,
#    'volumeEntered': 1500000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1482948711000,
#    'locationID': 60014659,
#    'minVolume': 1,
#    'orderID': 4730236421,
#    'orderRange': 'station',
#    'price': 4.25,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 7847451,
#    'volumeEntered': 10000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1483202713000,
#    'locationID': 1021705628874,
#    'minVolume': 1000,
#    'orderID': 4727637102,
#    'orderRange': '5',
#    'price': 4.06,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 161739297,
#    'volumeEntered': 200000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1483058760000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4731817819,
#    'orderRange': 'station',
#    'price': 4.05,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 10000000,
#    'volumeEntered': 10000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1483111252000,
#    'locationID': 60001873,
#    'minVolume': 1,
#    'orderID': 3664144403,
#    'orderRange': 'solarsystem',
#    'price': 4.04,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 108280678,
#    'volumeEntered': 120000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1482827593000,
#    'locationID': 60004210,
#    'minVolume': 1,
#    'orderID': 4725545268,
#    'orderRange': '3',
#    'price': 4.03,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 98266117,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1482987949000,
#    'locationID': 60002284,
#    'minVolume': 1,
#    'orderID': 4730814840,
#    'orderRange': 'solarsystem',
#    'price': 4.02,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 10000000,
#    'volumeEntered': 10000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1482585287000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4725469328,
#    'orderRange': 'station',
#    'price': 4.01,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 100000000,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 30,
#    'issued': 1482938784000,
#    'locationID': 1022719559274,
#    'minVolume': 1,
#    'orderID': 4730065968,
#    'orderRange': '1',
#    'price': 4,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 249999605,
#    'volumeEntered': 250000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1482942647000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4730119998,
#    'orderRange': '5',
#    'price': 3.92,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 18239,
#    'volumeEntered': 100000},
#   {'buy': True,
#    'duration': 30,
#    'issued': 1482418066000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4723166699,
#    'orderRange': 'station',
#    'price': 3.54,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1000000,
#    'volumeEntered': 1000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1482100664000,
#    'locationID': 1021705628874,
#    'minVolume': 1,
#    'orderID': 4718867273,
#    'orderRange': '1',
#    'price': 3.53,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 35000000,
#    'volumeEntered': 35000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1483134591000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4732829596,
#    'orderRange': 'station',
#    'price': 3.5,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 432000,
#    'volumeEntered': 432000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1483220494000,
#    'locationID': 1021705628874,
#    'minVolume': 1,
#    'orderID': 4733937435,
#    'orderRange': 'region',
#    'price': 3,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 9558129,
#    'volumeEntered': 10000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1480543953000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4696407011,
#    'orderRange': 'station',
#    'price': 2.03,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 6500000,
#    'volumeEntered': 6500000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1482374428000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4722693092,
#    'orderRange': '40',
#    'price': 1,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 94442990,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1481398638000,
#    'locationID': 1021705628874,
#    'minVolume': 1,
#    'orderID': 4708497872,
#    'orderRange': '1',
#    'price': 0.22,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 100000000,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 7,
#    'issued': 1482703689000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4727051122,
#    'orderRange': '3',
#    'price': 0.1,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 20000000,
#    'volumeEntered': 20000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1482100028000,
#    'locationID': 60004051,
#    'minVolume': 1,
#    'orderID': 4718854361,
#    'orderRange': '40',
#    'price': 0.07,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 100000000,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1480879533000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4701331362,
#    'orderRange': 'station',
#    'price': 0.06,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 100000000,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1479656464000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4647080938,
#    'orderRange': '40',
#    'price': 0.05,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 99582322,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1477261861000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4660693701,
#    'orderRange': '40',
#    'price': 0.04,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 2147459887,
#    'volumeEntered': 2147483647},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1476478191000,
#    'locationID': 60004048,
#    'minVolume': 1,
#    'orderID': 4653737048,
#    'orderRange': '40',
#    'price': 0.03,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 98404473,
#    'volumeEntered': 100000000},
#   {'buy': True,
#    'duration': 90,
#    'issued': 1478633453000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4672262015,
#    'orderRange': 'station',
#    'price': 0.01,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 300000000,
#    'volumeEntered': 300000000},
#   {'buy': False,
#    'duration': 1,
#    'issued': 1483226327000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4734004757,
#    'orderRange': 'region',
#    'price': 4.28,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 69699,
#    'volumeEntered': 103750},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483171052000,
#    'locationID': 60007498,
#    'minVolume': 1,
#    'orderID': 4733287152,
#    'orderRange': 'region',
#    'price': 4.69,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 857984,
#    'volumeEntered': 5612007},
#   {'buy': False,
#    'duration': 7,
#    'issued': 1483218235000,
#    'locationID': 60006424,
#    'minVolume': 1,
#    'orderID': 4733909056,
#    'orderRange': 'region',
#    'price': 4.78,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 4810649,
#    'volumeEntered': 4810649},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1483206083000,
#    'locationID': 60014659,
#    'minVolume': 1,
#    'orderID': 4733743885,
#    'orderRange': 'region',
#    'price': 4.8,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 82907,
#    'volumeEntered': 103178},
#   {'buy': False,
#    'duration': 7,
#    'issued': 1483173183000,
#    'locationID': 60000904,
#    'minVolume': 1,
#    'orderID': 4733309024,
#    'orderRange': 'region',
#    'price': 4.9,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1879491,
#    'volumeEntered': 1879491},
#   {'buy': False,
#    'duration': 3,
#    'issued': 1483145574000,
#    'locationID': 60004228,
#    'minVolume': 1,
#    'orderID': 4733004460,
#    'orderRange': 'region',
#    'price': 4.92,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 146940,
#    'volumeEntered': 386389},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482835462000,
#    'locationID': 60010819,
#    'minVolume': 1,
#    'orderID': 4728695647,
#    'orderRange': 'region',
#    'price': 4.97,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 313,
#    'volumeEntered': 923587},
#   {'buy': False,
#    'duration': 14,
#    'issued': 1483226970000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4734012460,
#    'orderRange': 'region',
#    'price': 4.98,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 18203348,
#    'volumeEntered': 93203348},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483053049000,
#    'locationID': 60003178,
#    'minVolume': 1,
#    'orderID': 4731726787,
#    'orderRange': 'region',
#    'price': 4.99,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1430977,
#    'volumeEntered': 31571377},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1483075669000,
#    'locationID': 60014659,
#    'minVolume': 1,
#    'orderID': 4732015784,
#    'orderRange': 'region',
#    'price': 5,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 31955,
#    'volumeEntered': 31955},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1482713380000,
#    'locationID': 60002818,
#    'minVolume': 1,
#    'orderID': 4727179352,
#    'orderRange': 'region',
#    'price': 5.01,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 181207,
#    'volumeEntered': 181207},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1483226874000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4733958972,
#    'orderRange': 'region',
#    'price': 5.04,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 216035544,
#    'volumeEntered': 279747003},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483226470000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4734006417,
#    'orderRange': 'region',
#    'price': 5.05,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 284908507,
#    'volumeEntered': 286799330},
#   {'buy': False,
#    'duration': 1,
#    'issued': 1483165985000,
#    'locationID': 60000655,
#    'minVolume': 1,
#    'orderID': 4733232986,
#    'orderRange': 'region',
#    'price': 5.07,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 7991,
#    'volumeEntered': 7991},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483215235000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4733872149,
#    'orderRange': 'region',
#    'price': 5.09,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 47683843,
#    'volumeEntered': 151742512},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1483136727000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4732869553,
#    'orderRange': 'region',
#    'price': 5.1,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 48785194,
#    'volumeEntered': 103945003},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482601251000,
#    'locationID': 60000448,
#    'minVolume': 1,
#    'orderID': 4725716294,
#    'orderRange': 'region',
#    'price': 5.11,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 473,
#    'volumeEntered': 9473},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482315067000,
#    'locationID': 60013045,
#    'minVolume': 1,
#    'orderID': 4721808779,
#    'orderRange': 'region',
#    'price': 5.12,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 80527,
#    'volumeEntered': 80527},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483093219000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4732193443,
#    'orderRange': 'region',
#    'price': 5.13,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 114509016,
#    'volumeEntered': 276929603},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483085097000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4732109315,
#    'orderRange': 'region',
#    'price': 5.15,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 290865838,
#    'volumeEntered': 290865838},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483076309000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4732021836,
#    'orderRange': 'region',
#    'price': 5.16,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1486362592,
#    'volumeEntered': 1486362592},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482556979000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4725141509,
#    'orderRange': 'region',
#    'price': 5.17,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 471384990,
#    'volumeEntered': 471384990},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482512154000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4724477047,
#    'orderRange': 'region',
#    'price': 5.18,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 172145558,
#    'volumeEntered': 172145558},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483122143000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4706195881,
#    'orderRange': 'region',
#    'price': 5.19,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 450000000,
#    'volumeEntered': 450000000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483077656000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4732035985,
#    'orderRange': 'region',
#    'price': 5.2,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 53123,
#    'volumeEntered': 53123},
#   {'buy': False,
#    'duration': 7,
#    'issued': 1482758569000,
#    'locationID': 60000361,
#    'minVolume': 1,
#    'orderID': 4727597844,
#    'orderRange': 'region',
#    'price': 5.21,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 8375,
#    'volumeEntered': 8375},
#   {'buy': False,
#    'duration': 7,
#    'issued': 1483132011000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4732783920,
#    'orderRange': 'region',
#    'price': 5.22,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 998367,
#    'volumeEntered': 998367},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483183882000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4733417226,
#    'orderRange': 'region',
#    'price': 5.24,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 121852,
#    'volumeEntered': 121852},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1483060463000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4731842468,
#    'orderRange': 'region',
#    'price': 5.25,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 5327929,
#    'volumeEntered': 5327929},
#   {'buy': False,
#    'duration': 14,
#    'issued': 1482969214000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4730590565,
#    'orderRange': 'region',
#    'price': 5.29,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 55000,
#    'volumeEntered': 55000},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1481975342000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4716622766,
#    'orderRange': 'region',
#    'price': 5.3,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 72064095,
#    'volumeEntered': 88461250},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1481841884000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4714873112,
#    'orderRange': 'region',
#    'price': 5.32,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 7543718,
#    'volumeEntered': 7543718},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1482363708000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4722555007,
#    'orderRange': 'region',
#    'price': 5.33,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 420,
#    'volumeEntered': 420},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482983662000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4730767693,
#    'orderRange': 'region',
#    'price': 5.35,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 987500,
#    'volumeEntered': 987500},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1481399753000,
#    'locationID': 60000361,
#    'minVolume': 1,
#    'orderID': 4708522100,
#    'orderRange': 'region',
#    'price': 5.42,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 18644,
#    'volumeEntered': 18644},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1481383296000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4708159164,
#    'orderRange': 'region',
#    'price': 5.43,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 21787892,
#    'volumeEntered': 21787892},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1481953965000,
#    'locationID': 60000364,
#    'minVolume': 1,
#    'orderID': 4716363155,
#    'orderRange': 'region',
#    'price': 5.45,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 313044,
#    'volumeEntered': 313044},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482422355000,
#    'locationID': 60002050,
#    'minVolume': 1,
#    'orderID': 4723228658,
#    'orderRange': 'region',
#    'price': 5.46,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1703,
#    'volumeEntered': 1703},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483086390000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4732121674,
#    'orderRange': 'region',
#    'price': 5.5,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 8378,
#    'volumeEntered': 8378},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1482996078000,
#    'locationID': 60001633,
#    'minVolume': 1,
#    'orderID': 4730894945,
#    'orderRange': 'region',
#    'price': 5.51,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 153847,
#    'volumeEntered': 19156456},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1481835897000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4714766778,
#    'orderRange': 'region',
#    'price': 5.52,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1000000,
#    'volumeEntered': 1000000},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1481551052000,
#    'locationID': 60003466,
#    'minVolume': 1,
#    'orderID': 4710795153,
#    'orderRange': 'region',
#    'price': 5.54,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 848873,
#    'volumeEntered': 1907100},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1481096678000,
#    'locationID': 60004225,
#    'minVolume': 1,
#    'orderID': 4704301400,
#    'orderRange': 'region',
#    'price': 5.6,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 10209,
#    'volumeEntered': 10500},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1481485568000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4709949469,
#    'orderRange': 'region',
#    'price': 5.64,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 10000000,
#    'volumeEntered': 10000000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1481922159000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4715910778,
#    'orderRange': 'region',
#    'price': 5.65,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 8089230,
#    'volumeEntered': 8089230},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482060787000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4718035323,
#    'orderRange': 'region',
#    'price': 5.7,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1648444,
#    'volumeEntered': 1648444},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482671833000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4726549643,
#    'orderRange': 'region',
#    'price': 5.74,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 174964869,
#    'volumeEntered': 174964869},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480861638000,
#    'locationID': 60006430,
#    'minVolume': 1,
#    'orderID': 4700926012,
#    'orderRange': 'region',
#    'price': 5.75,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 71250830,
#    'volumeEntered': 71250830},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1480695426000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4698278792,
#    'orderRange': 'region',
#    'price': 5.78,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 898241,
#    'volumeEntered': 898241},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480553917000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4696548276,
#    'orderRange': 'region',
#    'price': 5.8,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 500,
#    'volumeEntered': 500},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480441880000,
#    'locationID': 60003004,
#    'minVolume': 1,
#    'orderID': 4694976237,
#    'orderRange': 'region',
#    'price': 5.81,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 27428,
#    'volumeEntered': 27430},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480639672000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4697666351,
#    'orderRange': 'region',
#    'price': 5.83,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 449,
#    'volumeEntered': 449},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480559973000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4696623947,
#    'orderRange': 'region',
#    'price': 5.84,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 113996953,
#    'volumeEntered': 113996953},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483219363000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4731549063,
#    'orderRange': 'region',
#    'price': 5.87,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 317529,
#    'volumeEntered': 1000000},
#   {'buy': False,
#    'duration': 3,
#    'issued': 1483219087000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4732146780,
#    'orderRange': 'region',
#    'price': 5.88,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 42977,
#    'volumeEntered': 234161},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480296998000,
#    'locationID': 60004243,
#    'minVolume': 1,
#    'orderID': 4693133188,
#    'orderRange': 'region',
#    'price': 5.89,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 55533,
#    'volumeEntered': 262495},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482758244000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4727593625,
#    'orderRange': 'region',
#    'price': 5.93,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 16214960,
#    'volumeEntered': 16214960},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1481275551000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4706623578,
#    'orderRange': 'region',
#    'price': 5.94,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 55890035,
#    'volumeEntered': 55890035},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480625589000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4697450343,
#    'orderRange': 'region',
#    'price': 5.95,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 3576300,
#    'volumeEntered': 3576300},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1481799554000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4714236346,
#    'orderRange': 'region',
#    'price': 5.98,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 182150153,
#    'volumeEntered': 182150153},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483096794000,
#    'locationID': 60004444,
#    'minVolume': 1,
#    'orderID': 4732226085,
#    'orderRange': 'region',
#    'price': 5.99,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 85,
#    'volumeEntered': 85},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479919631000,
#    'locationID': 60012718,
#    'minVolume': 1,
#    'orderID': 4687227000,
#    'orderRange': 'region',
#    'price': 6,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 520103,
#    'volumeEntered': 544129},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483001748000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4730952610,
#    'orderRange': 'region',
#    'price': 6.02,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 29804337,
#    'volumeEntered': 29804337},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479988305000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4688129634,
#    'orderRange': 'region',
#    'price': 6.04,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 6000000,
#    'volumeEntered': 6000000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480007927000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4688465665,
#    'orderRange': 'region',
#    'price': 6.05,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 48602964,
#    'volumeEntered': 48602964},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480964476000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4702503505,
#    'orderRange': 'region',
#    'price': 6.09,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 41909,
#    'volumeEntered': 41909},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480448038000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4695094410,
#    'orderRange': 'region',
#    'price': 6.1,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 13382565,
#    'volumeEntered': 13382565},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479947631000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4687752285,
#    'orderRange': 'region',
#    'price': 6.12,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 900949,
#    'volumeEntered': 900949},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480880358000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4701349628,
#    'orderRange': 'region',
#    'price': 6.14,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 100000000,
#    'volumeEntered': 100000000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479253355000,
#    'locationID': 60010459,
#    'minVolume': 1,
#    'orderID': 4677909645,
#    'orderRange': 'region',
#    'price': 6.16,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 196921,
#    'volumeEntered': 229726},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479804196000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4685637994,
#    'orderRange': 'region',
#    'price': 6.19,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1796388,
#    'volumeEntered': 1796388},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479911057000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4687087329,
#    'orderRange': 'region',
#    'price': 6.2,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 83307123,
#    'volumeEntered': 83307123},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479770329000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4685244987,
#    'orderRange': 'region',
#    'price': 6.24,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 9338332,
#    'volumeEntered': 9338332},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1481498622000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4684483162,
#    'orderRange': 'region',
#    'price': 6.25,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 46640932,
#    'volumeEntered': 63862461},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479825978000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4685874408,
#    'orderRange': 'region',
#    'price': 6.26,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 100000000,
#    'volumeEntered': 100000000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479643988000,
#    'locationID': 60010456,
#    'minVolume': 1,
#    'orderID': 4683140017,
#    'orderRange': 'region',
#    'price': 6.3,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 6960023,
#    'volumeEntered': 6960023},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479715728000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4684417719,
#    'orderRange': 'region',
#    'price': 6.31,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 50000000,
#    'volumeEntered': 50000000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479783733000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4685420860,
#    'orderRange': 'region',
#    'price': 6.36,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 20898875,
#    'volumeEntered': 20898875},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479803062000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4685625845,
#    'orderRange': 'region',
#    'price': 6.39,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 33079867,
#    'volumeEntered': 33079867},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479564707000,
#    'locationID': 60003049,
#    'minVolume': 1,
#    'orderID': 4681792424,
#    'orderRange': 'region',
#    'price': 6.4,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 308587,
#    'volumeEntered': 135135835},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479565346000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4681804391,
#    'orderRange': 'region',
#    'price': 6.45,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 673201903,
#    'volumeEntered': 673201903},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480970339000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4702619555,
#    'orderRange': 'region',
#    'price': 6.5,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 2147483647,
#    'volumeEntered': 2147483647},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479683319000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4684025125,
#    'orderRange': 'region',
#    'price': 6.55,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 2146385,
#    'volumeEntered': 2146385},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479562806000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4681757471,
#    'orderRange': 'region',
#    'price': 6.57,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 2282,
#    'volumeEntered': 2282},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479560240000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4681637403,
#    'orderRange': 'region',
#    'price': 6.7,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 57633272,
#    'volumeEntered': 100000000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479560057000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4681708628,
#    'orderRange': 'region',
#    'price': 6.71,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1341830,
#    'volumeEntered': 7157768},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479558888000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4681689358,
#    'orderRange': 'region',
#    'price': 6.75,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 126661444,
#    'volumeEntered': 150000000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479750881000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4684862330,
#    'orderRange': 'region',
#    'price': 6.8,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 10000,
#    'volumeEntered': 10000},
#   {'buy': False,
#    'duration': 14,
#    'issued': 1483053678000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4731737555,
#    'orderRange': 'region',
#    'price': 7,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 665858,
#    'volumeEntered': 665858},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479557455000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4681666769,
#    'orderRange': 'region',
#    'price': 7.28,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 164455955,
#    'volumeEntered': 164683935},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479289048000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4678260794,
#    'orderRange': 'region',
#    'price': 7.3,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1508235542,
#    'volumeEntered': 1543431331},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1478079411000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4632008950,
#    'orderRange': 'region',
#    'price': 7.35,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 117783421,
#    'volumeEntered': 391573035},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480711421000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4698572263,
#    'orderRange': 'region',
#    'price': 7.5,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 200000,
#    'volumeEntered': 200000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479892471000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4686880621,
#    'orderRange': 'region',
#    'price': 7.67,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 200000,
#    'volumeEntered': 200000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480181280000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4691038023,
#    'orderRange': 'region',
#    'price': 7.81,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 21222143,
#    'volumeEntered': 21222143},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1483024150000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4731199195,
#    'orderRange': 'region',
#    'price': 7.88,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 794495,
#    'volumeEntered': 794495},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1478247548000,
#    'locationID': 60003397,
#    'minVolume': 1,
#    'orderID': 4668652750,
#    'orderRange': 'region',
#    'price': 7.95,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 879,
#    'volumeEntered': 62684},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479319207000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4678613063,
#    'orderRange': 'region',
#    'price': 7.99,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1039171,
#    'volumeEntered': 2000000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1478130240000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4667785981,
#    'orderRange': 'region',
#    'price': 8,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 374824,
#    'volumeEntered': 500000},
#   {'buy': False,
#    'duration': 7,
#    'issued': 1483031607000,
#    'locationID': 60002425,
#    'minVolume': 1,
#    'orderID': 4731340364,
#    'orderRange': 'region',
#    'price': 8.03,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 23844,
#    'volumeEntered': 24444},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479276657000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4678146900,
#    'orderRange': 'region',
#    'price': 8.56,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 15250,
#    'volumeEntered': 15250},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482951156000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4730280765,
#    'orderRange': 'region',
#    'price': 8.9,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 319270,
#    'volumeEntered': 319270},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482047892000,
#    'locationID': 60002425,
#    'minVolume': 1,
#    'orderID': 4717853785,
#    'orderRange': 'region',
#    'price': 8.91,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 131196890,
#    'volumeEntered': 131197190},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1477376048000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4555636520,
#    'orderRange': 'region',
#    'price': 8.96,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 653788,
#    'volumeEntered': 10000000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1481082277000,
#    'locationID': 60004048,
#    'minVolume': 1,
#    'orderID': 4704153614,
#    'orderRange': 'region',
#    'price': 8.99,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 9493301,
#    'volumeEntered': 20000000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1480456168000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4695249731,
#    'orderRange': 'region',
#    'price': 9.62,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 21111,
#    'volumeEntered': 21111},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1480834661000,
#    'locationID': 60002353,
#    'minVolume': 1,
#    'orderID': 4700509705,
#    'orderRange': 'region',
#    'price': 9.64,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 188745,
#    'volumeEntered': 394076},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1476643536000,
#    'locationID': 60012667,
#    'minVolume': 1,
#    'orderID': 4655321688,
#    'orderRange': 'region',
#    'price': 9.97,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1808068,
#    'volumeEntered': 2685188},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479722892000,
#    'locationID': 60002359,
#    'minVolume': 1,
#    'orderID': 4653192595,
#    'orderRange': 'region',
#    'price': 9.98,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 43069625,
#    'volumeEntered': 74884594},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1476317933000,
#    'locationID': 60002359,
#    'minVolume': 1,
#    'orderID': 4652528843,
#    'orderRange': 'region',
#    'price': 9.99,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 5208286,
#    'volumeEntered': 5208286},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482090672000,
#    'locationID': 60005455,
#    'minVolume': 1,
#    'orderID': 4718647162,
#    'orderRange': 'region',
#    'price': 10,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 3000,
#    'volumeEntered': 3000},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479222458000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4677414908,
#    'orderRange': 'region',
#    'price': 12,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 17070,
#    'volumeEntered': 17070},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1477457046000,
#    'locationID': 60003079,
#    'minVolume': 1,
#    'orderID': 4662198165,
#    'orderRange': 'region',
#    'price': 16,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1873484,
#    'volumeEntered': 1873484},
#   {'buy': False,
#    'duration': 3,
#    'issued': 1483212387000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4733833887,
#    'orderRange': 'region',
#    'price': 20,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 18549,
#    'volumeEntered': 18549},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1482452539000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4723760126,
#    'orderRange': 'region',
#    'price': 25,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 492956,
#    'volumeEntered': 492956},
#   {'buy': False,
#    'duration': 30,
#    'issued': 1482107769000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4718987796,
#    'orderRange': 'region',
#    'price': 102.04,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1,
#    'volumeEntered': 1},
#   {'buy': False,
#    'duration': 3,
#    'issued': 1483159609000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4733165780,
#    'orderRange': 'region',
#    'price': 1000,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 4791,
#    'volumeEntered': 4791},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1479536193000,
#    'locationID': 60015027,
#    'minVolume': 1,
#    'orderID': 4681406417,
#    'orderRange': 'region',
#    'price': 10000,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1,
#    'volumeEntered': 1},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1481393854000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4708400130,
#    'orderRange': 'region',
#    'price': 1000000,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1,
#    'volumeEntered': 1},
#   {'buy': False,
#    'duration': 90,
#    'issued': 1482614246000,
#    'locationID': 60003760,
#    'minVolume': 1,
#    'orderID': 4725922117,
#    'orderRange': 'region',
#    'price': 1873484,
#    'regionID': 10000002,
#    'typeID': 34,
#    'volume': 1,
#    'volumeEntered': 1}],
#  'regionID': 10000002,
#  'typeID': 34}

# %%
# Orders are ordered with buys first, descending in price, followed by sells in ascending price
# Let's pull these out to simplify things
buy = [x for x in sample_book['orders'] if x['buy'] and x['locationID'] == station_id ]
sell = [x for x in sample_book['orders'] if not x['buy'] and x['locationID'] == station_id ]

# %%
# By construction, spread is now just the difference in price between the first buy order and 
# the first sell order.  However, there are some corner cases where one or both of these
# lists are empty.  In those cases, there isn't a spread.  Here's a function which 
# computes the spread
def compute_spread(buy, sell):
    if len(buy) == 0 or len(sell) == 0:
        return None
    return sell[0]['price'] - buy[0]['price']

compute_spread(buy, sell)
# Out:
# 0.3200000000000003

# %%
# All that remains is to compute the spread for all snapshots for the target day.
# We'll do that by iterating over 288 intervals from our start time, retrieving 
# the order book at each step.  This will require 288 calls to the market data service
# so this will take a few minutes to run.
current_time = compute_date
five_minute_delta = datetime.timedelta(minutes=5)
spreads = []
for _ in range(288):
    print("Computing spread for %s" % str(current_time), end="...")
    next_book = mdc_client.MarketData.book(typeID=type_id, regionID=region_id, date=str(current_time) + " UTC").result()[0]
    buy = [x for x in next_book['orders'] if x['buy'] and x['locationID'] == station_id ]
    sell = [x for x in next_book['orders'] if not x['buy'] and x['locationID'] == station_id ]
    next_spread = compute_spread(buy, sell)
    if next_spread is not None:
        spreads.append(next_spread)
    current_time += five_minute_delta
    print("done")

np.average(spreads)
# Out:
# Computing spread for 2017-01-01 00:00:00...done
# Computing spread for 2017-01-01 00:05:00...done
# Computing spread for 2017-01-01 00:10:00...done
# Computing spread for 2017-01-01 00:15:00...done
# Computing spread for 2017-01-01 00:20:00...done
# Computing spread for 2017-01-01 22:45:00...done
# Computing spread for 2017-01-01 22:50:00...done
# Computing spread for 2017-01-01 22:55:00...done
# Computing spread for 2017-01-01 23:00:00...done
# Computing spread for 2017-01-01 23:05:00...done
# Computing spread for 2017-01-01 23:10:00...done
# Computing spread for 2017-01-01 23:15:00...done
# Computing spread for 2017-01-01 23:20:00...done
# Computing spread for 2017-01-01 23:25:00...done
# Computing spread for 2017-01-01 23:30:00...done
# Computing spread for 2017-01-01 23:35:00...done
# Computing spread for 2017-01-01 23:40:00...done
# Computing spread for 2017-01-01 23:45:00...done
# Computing spread for 2017-01-01 23:50:00...done
# Computing spread for 2017-01-01 23:55:00...done
# 0.24631944444444442

# %%
# Now let's look at library support which eliminates or simplifies some of the steps above.
#
# As in the first example, we start with library functions that can be used to download
# book data to local storage.  Let's say it again so we don't forget: book data is quite large,
# make sure you're on a reasonably fast connection before you download lots of data
from evekit.online.Download import download_order_book_range

# The book downloader lets you filter to specific types and regions for a date range.
# In this example, we only need Tritanium in The Forge on our target date, so this should
# download relatively quickly.  We'll store the download in our local directory in "tree"
# format (i.e. YYYY/MM/DD/files...)
download_order_book_range([compute_date], ".", types=[type_id], regions=[region_id], config={'verbose': True, 'tree': True})
# Out:
# Downloading 2017-01-01 00:00:00...done

# %%
# Previously, we iterated through each snapshot for our target date.  We can do this 
# a bit more tersely using the OrderBook library and loading the data in a Pandas DataFrame.
# This call creates a DataFrame where each row is an individual order indexed by 
# the time of the snapshot containing the order.  The DataFrame also contains type_id
# and region_id columns which can be used to filter as needed.
from evekit.marketdata import OrderBook

order_book = OrderBook.get_data_frame(dates=[compute_date], types=[type_id], regions=[region_id], 
                                      config=dict(local_storage=".", tree=True, skip_missing=True, verbose=True))

order_book
# Out:
# Retrieving 2017-01-01 00:00:00...done
#                        buy                date  duration              issued  \
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-14 08:49:22
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-30 00:11:05
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        30 2016-12-29 12:22:35
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-29 14:05:45
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-29 15:06:24
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-31 17:20:36
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-29 17:47:28
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        30 2016-12-13 03:24:26
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-31 18:00:40
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        30 2016-12-04 18:43:39
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-24 23:33:48
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-03 07:55:24
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00         7 2016-12-30 12:08:57
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-04 17:22:09
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00         3 2016-12-29 03:13:01
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        30 2016-12-18 19:04:59
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-03 17:01:01
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-22 03:49:25
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-24 09:00:18
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-31 16:57:47
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-28 18:11:51
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-31 16:45:13
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-30 00:46:00
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-30 15:20:52
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-27 08:33:13
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-29 05:05:49
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-24 13:14:47
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        30 2016-12-28 15:26:24
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        90 2016-12-28 16:30:47
# 2017-01-01 00:00:00   True 2017-01-01 00:00:00        30 2016-12-22 14:47:46
# ...                    ...                 ...       ...                 ...
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-11-19 12:10:55
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-11-16 09:37:28
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-11-02 09:36:51
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-12-02 20:43:41
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-11-23 09:14:31
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-11-26 17:28:00
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-12-29 15:09:10
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-11-04 08:19:08
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-11-16 18:00:07
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-11-02 23:44:00
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00         7 2016-12-29 17:13:27
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-11-16 06:10:57
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-12-28 18:52:36
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-12-18 07:58:12
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-10-25 06:14:08
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-12-07 03:44:37
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-11-29 21:49:28
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        30 2016-12-04 06:57:41
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-10-16 18:45:36
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-11-21 10:08:12
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-10-13 00:18:53
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-12
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-12-10 18:17:34
# 2017-01-01 23:55:00  False 2017-01-01 23:55:00        90 2016-12-24 21:17:26
#
#                      location_id  min_volume    order_id order_range  \
# 2017-01-01 00:00:00     60003760           1  4733760768           1
# 2017-01-01 00:00:00     60003760           1  4701276671     station
# 2017-01-01 00:00:00     60003760           1  4699131616     station
# 2017-01-01 00:00:00     60003760           1  4701158083     station
# 2017-01-01 00:00:00     60003760           1  4731817819     station
# 2017-01-01 00:00:00     60003760           1  4725469328     station
# 2017-01-01 00:00:00     60003760           1  4730119998           5
# 2017-01-01 00:00:00     60003760           1  4723166699     station
# 2017-01-01 00:00:00     60003760           1  4732829596     station
# 2017-01-01 00:00:00     60003760           1  4696407011     station
# 2017-01-01 00:00:00     60003760           1  4722693092          40
# 2017-01-01 00:00:00     60003760           1  4727051122           3
# 2017-01-01 00:00:00     60003760           1  4701331362     station
# 2017-01-01 00:00:00     60003760           1  4647080938          40
# 2017-01-01 00:00:00     60003760           1  4660693701          40
# 2017-01-01 00:00:00     60003760           1  4672262015     station
# 2017-01-01 00:00:00     60003760           1  4734012460      region
# 2017-01-01 00:00:00     60003760           1  4733958972      region
# 2017-01-01 00:00:00     60003760           1  4734006417      region
# 2017-01-01 00:00:00     60003760           1  4733872149      region
# 2017-01-01 00:00:00     60003760           1  4732869553      region
# 2017-01-01 00:00:00     60003760           1  4732193443      region
# 2017-01-01 00:00:00     60003760           1  4732109315      region
# 2017-01-01 00:00:00     60003760           1  4732021836      region
# 2017-01-01 00:00:00     60003760           1  4725141509      region
# 2017-01-01 00:00:00     60003760           1  4724477047      region
# 2017-01-01 00:00:00     60003760           1  4706195881      region
# 2017-01-01 00:00:00     60003760           1  4732035985      region
# 2017-01-01 00:00:00     60003760           1  4732783920      region
# 2017-01-01 00:00:00     60003760           1  4733417226      region
# ...                          ...         ...         ...         ...
# 2017-01-01 23:55:00     60003760           1  4702503505      region
# 2017-01-01 23:55:00     60003760           1  4695094410      region
# 2017-01-01 23:55:00     60003760           1  4687752285      region
# 2017-01-01 23:55:00     60003760           1  4701349628      region
# 2017-01-01 23:55:00     60003760           1  4685637994      region
# 2017-01-01 23:55:00     60003760           1  4687087329      region
# 2017-01-01 23:55:00     60003760           1  4685244987      region
# 2017-01-01 23:55:00     60003760           1  4684483162      region
# 2017-01-01 23:55:00     60003760           1  4685874408      region
# 2017-01-01 23:55:00     60003760           1  4684417719      region
# 2017-01-01 23:55:00     60003760           1  4685420860      region
# 2017-01-01 23:55:00     60003760           1  4685625845      region
# 2017-01-01 23:55:00     60003760           1  4681804391      region
# 2017-01-01 23:55:00     60003760           1  4684025125      region
# 2017-01-01 23:55:00     60003760           1  4681757471      region
# 2017-01-01 23:55:00     60003760           1  4681637403      region
# 2017-01-01 23:55:00     60003760           1  4681708628      region
# 2017-01-01 23:55:00     60003760           1  4681689358      region
# 2017-01-01 23:55:00     60003760           1  4684862330      region
# 2017-01-01 23:55:00     60003760           1  4681666769      region
# 2017-01-01 23:55:00     60003760           1  4678260794      region
# 2017-01-01 23:55:00     60003760           1  4632008950      region
# 2017-01-01 23:55:00     60003760           1  4698572263      region
# 2017-01-01 23:55:00     60003760           1  4686880621      region
# 2017-01-01 23:55:00     60003760           1  4691038023      region
# 2017-01-01       34    78774738       200000000
# 2017-01-01       34   100000000       100000000
# 2017-01-01       34   100000000       100000000
# 2017-01-01       34    10000000        10000000
# 2017-01-01       34   100000000       100000000
# 2017-01-01       34       18239          100000
# 2017-01-01       34     1000000         1000000
# 2017-01-01       34      432000          432000
# 2017-01-01       34     6500000         6500000
# 2017-01-01       34    94442990       100000000
# 2017-01-01       34    20000000        20000000
# 2017-01-01       34   100000000       100000000
# 2017-01-01       34    99582322       100000000
# 2017-01-01       34  2147459887      2147483647
# 2017-01-01       34   300000000       300000000
# 2017-01-01       34    18203348        93203348
# 2017-01-01       34   216035544       279747003
# 2017-01-01       34   284908507       286799330
# 2017-01-01       34    47683843       151742512
# 2017-01-01       34    48785194       103945003
# 2017-01-01       34   114509016       276929603
# 2017-01-01       34   290865838       290865838
# 2017-01-01       34  1486362592      1486362592
# 2017-01-01       34   471384990       471384990
# 2017-01-01       34   172145558       172145558
# 2017-01-01       34   450000000       450000000
# 2017-01-01       34       53123           53123
# 2017-01-01       34      998367          998367
# 2017-01-01       34      121852          121852
# ...             ...         ...             ...
# 2017-01-01       34       41909           41909
# 2017-01-01       34    13382565        13382565
# 2017-01-01       34      900949          900949
# 2017-01-01       34   100000000       100000000
# 2017-01-01       34     1796388         1796388
# 2017-01-01       34    83307123        83307123
# 2017-01-01       34     9338332         9338332
# 2017-01-01       34    46640932        63862461
# 2017-01-01       34   100000000       100000000
# 2017-01-01       34    50000000        50000000
# 2017-01-01       34    20898875        20898875
# 2017-01-01       34    33079867        33079867
# 2017-01-01       34   673201903       673201903
# 2017-01-01       34  2147483647      2147483647
# 2017-01-01       34     2146385         2146385
# 2017-01-01       34        2282            2282
# 2017-01-01       34    57633272       100000000
# 2017-01-01       34     1341830         7157768
# 2017-01-01       34   126661444       150000000
# 2017-01-01       34       10000           10000
# 2017-01-01       34   164455955       164683935
# 2017-01-01       34  1508235542      1543431331
# 2017-01-01       34   117783421       391573035
# 2017-01-01       34      200000          200000
# 2017-01-01       34      200000          200000
# 2017-01-01       34    21222143        21222143
# 2017-01-01       34       15250           15250
# 2017-01-01       34           1               1
# 2017-01-01       34           1               1
# 2017-01-01       34           1               1
#
# [84 rows x 13 columns]

# %%
# We can implement a simple function to compute the spread given a group object DataFrame.
# Note that we still have to handle the case where there may be no buys or sells.  When
# we encounter such cases, we return a NaN which is conveniently ignored by the Pandas
# mean function.
#
def spread_df(df):
    if df[df.buy == True].index.size == 0 or df[df.buy == False].index.size == 0:
        return np.NaN

    return df[df.buy == False].sort_values('price', ascending=True).ix[0].price - \
           df[df.buy == True].sort_values('price', ascending=False).ix[0].price

spread_df(df)
# Out:
# 0.32000000000000028

# %%
# Finally, we can apply our spread function to the groups and compute the mean (which excludes NaN automatically)
groups.apply(spread_df).mean()
# Out:
# 0.24631944444444442

# %%
# Here's the whole thing as a one liner (except for the spread_df function)
#
order_book[order_book.location_id == station_id].groupby(order_book[order_book.location_id == station_id].index)\
                                                .apply(spread_df)\
                                                .mean()
# Out:
# 0.24631944444444442
