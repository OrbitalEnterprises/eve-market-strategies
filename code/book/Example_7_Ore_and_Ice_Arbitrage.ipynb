# %% [markdown]
# ### Example 7- Ore and Ice Arbitrage
#
# In this example, we'll look for arbitrage opportunities in a day of order book data for ore and ice materials.
# An arbitrage opportunity exists if ore or ice can be purchased at a low enough price such that the refined
# materials can be sold for a profit \(minus the refinement tax\).

# %%
# Standard imports
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline
# EveKit imports
from evekit.reference import Client
from evekit.util import convert_raw_time

# %%
# We'll use a day of order book data for all ore and ice types and their refined materials.
# This cell sets up our reference date, region and station.  The next cells derive the appropriate
# inventory types and retrieve appropriate market data.
#
sde_client = Client.SDE.get()
region_query = "{values: ['The Forge']}"
station_query = "{values: ['Jita IV - Moon 4 - Caldari Navy Assembly Plant']}"
region_id = sde_client.Map.getRegions(regionName=region_query).result()[0][0]['regionID']
station_id = sde_client.Station.getStations(stationName=station_query).result()[0][0]['stationID']
compute_date = datetime.datetime(2017, 1, 10)
print("Using region_id=%d, station_id=%d at %s" % (region_id, station_id, str(compute_date)))
# Out:
# Using region_id=10000002, station_id=60003760 at 2017-01-10 00:00:00

# %%
# Ore and Ice types are organized by inventory group.  There are 16 ore families and one ice family,
# each corresponding to an inventory group.  We first need to resolve these group IDs, then we
# can retrieve the corresponding types.
material_group_names = [ 'Veldspar', 'Scordite', 'Pyroxeres', 'Plagioclase', 'Omber', 'Kernite', 'Jaspet', 
                         'Hemorphite', 'Hedbergite', 'Gneiss', 'Dark Ochre', 'Spodumain', 'Crokite', 
                         'Bistot', 'Arkonor', 'Mercoxit', 'Ice' ]
group_name_query = "{values:[" + ",".join(map(lambda x : "'" + x + "'", material_group_names)) + "]}"
material_groups = Client.SDE.load_complete(sde_client.Inventory.getGroups, groupName=group_name_query)

# Next, we'll retrieve type information for all the inventory items in the requested groups
group_id_query = "{values:[" + ",".join([str(x['groupID']) for x in material_groups]) + "]}"
source_types = {}
for next_type in Client.SDE.load_complete(sde_client.Inventory.getTypes, groupID=group_id_query):
    if next_type['marketGroupID'] is not None:
        # We perform this check because the 'Ice' family in the SDE includes some non-refinable types
        # These are detectable by the lack of a market group ID.  We create a material_map entry
        # in preparation for the next step.
        next_type['material_map'] = {}
        source_types[next_type['typeID']] = next_type

# Finally, we'll determine the types which each source material can refine to.  We'll save this information
# as a map associated with each source type.
type_id_query = "{values:[" + ",".join([str(x) for x in source_types.keys()]) + "]}"
for next_mat in Client.SDE.load_complete(sde_client.Inventory.getTypeMaterials, typeID=type_id_query):
    source_types[next_mat['typeID']]['material_map'][next_mat['materialTypeID']] = next_mat

# %%
#
# WARNING: this cell will take some time to evaluate if your connection is slow
#
# Now we'll download a day of order book data for our source types and all of the refined materials.
# This isn't mandatory and if you'd prefer to load everything online on demand, you can remove the 
# "local_storage" argument from the order book functions below.  However, we strongly recommend 
# downloading order books to local storage to allow you to iterate more easily as you experiment.
download_types = set(source_types.keys())
for next_type in source_types.values():
    download_types = download_types.union(next_type['material_map'].keys())
    
from evekit.online.Download import download_order_book_range
download_order_book_range([compute_date], ".", types=download_types, regions=[region_id], 
                          config={'verbose': True, 'tree': True})
# Out:
# Downloading 2017-01-10 00:00:00...done

# %%
# We'll load order book data for the day into a DataFrame.
from evekit.marketdata import OrderBook
order_book = OrderBook.get_data_frame(dates=[compute_date], types=download_types, regions=[region_id], 
                                      config=dict(local_storage=".", tree=True, skip_missing=True, 
                                                  fill_gaps=True, verbose=True))
# Out:
# Retrieving 2017-01-10 00:00:00...done

# %% [markdown]
# An arbitrage opportunity exists for a source material if the following equation is positive:
#
# $\sum_i\left(v_i \times e \times (1 - t) \times p_b(c_i)\right) - \sum_i\left(v_i \times e \times s_t \times p_r(c_i)\right) - r_m \times p_a(r)$
#
# which can be simplifed to:
#
# $\sum_i\left(v_i \times e \times \left[ (1 - t) \times p_b(c_i) - s_t \times p_r(c_i)\right] \right) -  r_m \times p_a(r)$
#
# where:
#
# * $r$ - type ID of an ore or ice type to be refined.
# * $r_m$ - the amount of material required for one refinement cycle.
# * $e$ - refinement efficiency computed from station efficiency and player skills.
# * $m(r) \rightarrow {(c_1, v_1), ..., (c_n, v_n)}$ - a map from source material to a set of refined materials $(c_i, v_i)$ where $c_i$ represents the refined material type, and $v_i$ represents the ideal quantity produced when refining $r_m$ units of $r$.
# * $p_r(t)$ - the reference price for an asset \(such a price exists for all marketable EVE types\).
# * $p_a(t)$ - the current best ask price for an asset \(i.e. the minimum price at which the asset can be purchased\).
# * $p_b(t)$ - the current best bid price for an asset \(i.e. the maximum price at which the asset can be sold\).
# * $t$ - sales tax for the refining player.
# * $s_t$ - station refining tax.
#
# The type map `source_types` we created above can be used to determine values for $r_m$ and $m(r)$.  Values for $p_a$ and $p_b$ are found in the order book.  Values for $e$, $t$ and $s_t$ are constants determined by player skill, refinery location and player standing with the entity which owns the refining location.  We'll set these below.  Finally, $p_r$ is obtained from the [market prices endpoint](https://esi.tech.ccp.is/latest/#!/Market/get_markets_prices), specifically the "adjusted_price" field.  We don't have historic data for this endpoint, so for this example we'll re-use $p_b$.  A production quality version of this example would use `adjusted_price` from the endpoint.
#
# With this last assumption, the opportunity function becomes:
#
# $\sum_i\left(v_i \times e \times (1 - (t + s_t)) \times p_b(c_i) \right) -  r_m \times p_a(r)$
#
# The opportunity function is just a definition of the check that determines whether an opportunity is profitable.  An actual implementation of an arbitrage trading strategy will need to simulate buying source material from existing sell orders, and selling refined materials into existing buy orders.  The following pseudo-code describes a basic arbitrage opportunity finder for a day of order book data:
#
# ```
# for each snapshot S:
#   for each refineable asset r:
#     let r_m = minimum refinable volume for r
#     while profitable:
#       determine whether we can buy r_m units of r
#       if buy successful:
#         let cost = cost of buying r_m units of r
#         let gross = 0
#         compute the refined materials for r_m units of r
#         for each refined material m:
#           determine whether we can sell m
#           if sell successful:
#             let gross = gross + proceeds from selling m
#             let cost = cost + incremental reprocessing tax for m
#           else:
#             let gross = 0
#             break
#         if gross > cost:
#           record opportunity
# ```
#
# This opportunity finder considers all refinable assets for each snapshot.  The check for an opportunity consists of first attempting to buy enough volume of a refineable asset, then attempting to sell the refined materials.  If the gross proceeds from selling the refined materials exceeds the cost of buying the refined asset, plus reproccessing tax, then the opportunity is profitable.  We can determine whether it is possible to buy a refineable asset, or whether it is possible to sell a refined material, by consulting orders in the order book.  We maximize the profit for a given refineable asset by continuing to buy and refine until it is no longer profitable to do so.
#
# For the remainder of this example, we'll develop code to implement this opportunity finder.

# %%
# Set efficiency, tax rate and station tax.  These factors depend on players skills,
# refining location, and player standings with the owner of the refinery.

# This is the efficiency at a typical NPC station with max skills
efficiency = 0.5 * 1.15 * 1.1 * 1.1

# This is the sales tax at a typical NPC station with max skills
tax_rate = 0.01

# Station tax can be no greater than 0.05.  This value is zero if standings are 6.67 or better.
# As noted above, we're substituting order price for adjusted price.  From empirical observation,
# setting station_tax to 0.04 roughly approximates a station_tax of 0.05 with true adjusted prices.
# So we'll set station tax to 0.04 here.
station_tax = 0.04

# %%
# For our initial implementation of our strategy, we'll focus on just finding the first
# opportunity that exists for a given asset in a given snapshot.  This won't maximize profit
# for the opportunity, but is simpler to implement as a first cut.

# A key part of our strategy involves determing whether it is possible to buy or sell
# assets in a given snapshot.  We'll abstract this functionality into two separate functions.

# The following function checks whether it is possible to buy the given type at
# the given location in the given volume.  If a purchase is possible, then a list
# of the form [ {price=p1, volume=v1}, ..., {price=pn, volume=vn}] is returned where 
# pi gives a price and vi gives the volume that was purchased at that price.
def attempt_buy_type(buy_location_id, buy_type_id, buy_volume, snapshot):
    # Restrict to the given type and location
    by_type = snapshot[snapshot.type_id == buy_type_id]
    by_loc = by_type[by_type.location_id == buy_location_id]
    by_side = by_loc[by_loc.buy == False]
    # Attempt to buy from order list.  Recall that sell orders are ordered
    # low price to high price in the DataFrame.
    buy_orders = []
    for next_row in by_side.iterrows():
        order = next_row[1]
        if buy_volume >= order['min_volume']:
            amount = min(buy_volume, order['volume'])
            buy_orders.append(dict(price=order['price'], volume=amount))
            buy_volume -= amount
        if buy_volume == 0:
            # We've completely filled this order
            return buy_orders
    # If we never completely fill the order then return no orders
    return []

# %%
# This next function checks wheter it is possible to sell the given type from
# a given location at the given volume.  As you may recall from example 3, matching buy orders
# may be at remote locations.  We'll use our range checker from the TradingUtil library
# to help check for matches.
from evekit.marketdata import TradingUtil

# The result of this function will be a list [ {price=p1, volume=v1}, ..., {price=pn, volume=vn}] 
# such that pi gives a price, and vi gives the volume that was sold at that price.
def attempt_sell_type(sell_region_id, sell_location_id, sell_type_id, sell_volume, snapshot):
    config = dict(use_citadel=False)
    by_type = snapshot[snapshot.type_id == sell_type_id]
    by_side = by_type[by_type.buy == True]
    sell_orders = []
    # Attempt to sell to order list.  Recall that buy orders are ordered
    # high price to low price in the DataFrame.
    for next_row in by_side.iterrows():
        order = next_row[1]
        try:
            if sell_volume >= order['min_volume'] and \
               TradingUtil.check_range(sell_region_id, sell_location_id, order['location_id'], order['order_range'], config):
                amount = min(sell_volume, order['volume'])
                sell_orders.append(dict(price=order['price'], volume=amount))
                sell_volume -= amount
        except:
            # We'll get an exception if TradingUtil can't find the location of a player-owned
            # station.  We'll ignore those for now.  Change "use_citadel" to True above
            # if you'd like to attempt to resolve the location of these stations from a 
            # third party source.
            pass
        if sell_volume == 0:
            # We've completely filled this order
            return sell_orders
    # If we never completely fill the order then return no orders
    return []

# %%
# Now we can implement our basic opportunity checker.
def check_opportunities(order_book, type_map, station_id, region_id, efficiency, sales_tax, station_tax, verbose=False):
    if verbose:
        total_snapshots = len(order_book.groupby(order_book.index))
        print("Checking %d snapshots for opportunities" % total_snapshots)
    opportunities = []
    count = 0
    #
    # We'll iterate through every snapshot in the current order book
    for snapshot_group in order_book.groupby(order_book.index):
        # Each group is a pair (snapshot_time, snapshot_dataframe)
        snapshot_time = snapshot_group[0]
        snapshot = snapshot_group[1]
        if verbose:
            print("X", end='')
            count += 1
            if count % 72 == 0:
                print()
        #
        # Next we'll iterate through each source type looking for opportunities
        for source_type in type_map.values():
            #
            # First, attempt to buy enough material to refine
            required_volume = source_type['portionSize']
            buy_orders = attempt_buy_type(station_id, source_type['typeID'], required_volume, snapshot)
            if len(buy_orders) == 0:
                # Failed to buy enough, skip this source
                continue
            buy_total = np.sum([x['price'] * x['volume'] for x in buy_orders])
            #
            # Now attempt to sell all the refined materials
            sell_total = 0
            for next_mat in source_type['material_map'].values():
                # Output amount is determined by efficiency.  This is how much we have to sell
                output_amount = int(next_mat['quantity'] * efficiency)
                # Check whether we can sell this output.
                sell_orders = attempt_sell_type(region_id, station_id, next_mat['materialTypeID'], output_amount, snapshot)
                if len(sell_orders) == 0:
                    # We couldn't sell this material so no opportunity here
                    sell_total = 0
                    break
                # Add the profit from the sale less sales tax
                sell_total += (1 - sales_tax) * np.sum([x['price'] * x['volume'] for x in sell_orders])
                # Add the incremental refinement tax to the buy cost.
                # If we had actual adjusted_prices, we'd use those prices in place of x['price'] below.
                buy_total += station_tax * np.sum([x['price'] * x['volume'] for x in sell_orders])
            # Did we profit?
            if sell_total > buy_total:
                # Yes, record the result
                profit = sell_total - buy_total
                margin = profit/buy_total
                opportunities.append(dict(time=snapshot_time, profit=profit, margin=margin, type=source_type['typeName']))
    if verbose:
        print()
    return opportunities

# %%
# Now let's check for all opportunities for our day of book data
opportunities = check_opportunities(order_book, source_types, station_id, region_id, 
                                    efficiency, tax_rate, station_tax, verbose=True)
# Out:
# Checking 288 snapshots for opportunities
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
# Dump opportunities in a nice format
def display_opportunities(opps):
    for opp in opps:
        profit = "{:15,.2f}".format(opp['profit'])
        margin = "{:8.2f}".format(opp['margin'] * 100)
        print("ArbOpp time=%s  profit=%s  return=%s%%  type=%s" % (str(opp['time']), profit, margin, opp['type']))
    print("Total opportunities: %d" % len(opps))

# %%
# Let's take a look at the opportunities we found
display_opportunities(opportunities)
# Out:
# ArbOpp time=2017-01-10 00:50:00  profit=      10,757.88  return=    1.98%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 00:50:00  profit=       1,723.48  return=    0.46%  type=Compressed Bright Spodumain
# ArbOpp time=2017-01-10 00:55:00  profit=      10,757.88  return=    1.98%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 00:55:00  profit=       1,726.60  return=    0.46%  type=Compressed Bright Spodumain
# ArbOpp time=2017-01-10 01:00:00  profit=      10,757.88  return=    1.98%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 01:05:00  profit=      10,758.57  return=    1.98%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 01:05:00  profit=           0.15  return=    0.00%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 01:10:00  profit=      10,841.85  return=    1.99%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 01:10:00  profit=           1.62  return=    0.03%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 01:15:00  profit=      11,211.35  return=    2.06%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 01:15:00  profit=           1.62  return=    0.03%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 02:10:00  profit=           2.37  return=    0.04%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 02:15:00  profit=           2.37  return=    0.04%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 02:55:00  profit=       3,773.84  return=    0.65%  type=Compressed Monoclinic Bistot
# ArbOpp time=2017-01-10 03:00:00  profit=       3,773.84  return=    0.65%  type=Compressed Monoclinic Bistot
# ArbOpp time=2017-01-10 03:15:00  profit=         420.71  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:20:00  profit=         420.71  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:25:00  profit=         420.71  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:30:00  profit=      13,659.53  return=   32.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 03:30:00  profit=         420.71  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:35:00  profit=      13,659.53  return=   32.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 03:35:00  profit=         420.71  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:40:00  profit=      13,659.85  return=   32.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 03:40:00  profit=         420.88  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:45:00  profit=      13,659.85  return=   32.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 03:45:00  profit=         420.88  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:50:00  profit=      13,659.85  return=   32.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 03:50:00  profit=         420.88  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:55:00  profit=      13,659.85  return=   32.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 03:55:00  profit=         420.88  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:00:00  profit=      13,659.85  return=   32.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:00:00  profit=         420.88  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:05:00  profit=      13,660.85  return=   32.33%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:05:00  profit=       6,095.20  return=   17.33%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:05:00  profit=       4,421.05  return=   11.11%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:05:00  profit=         353.25  return=    1.80%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:10:00  profit=      13,661.55  return=   32.33%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:10:00  profit=       6,095.20  return=   17.33%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:10:00  profit=       4,421.05  return=   11.11%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:10:00  profit=         354.22  return=    1.81%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:10:00  profit=          44.86  return=    3.12%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:15:00  profit=      13,661.76  return=   32.33%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:15:00  profit=       6,095.30  return=   17.33%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:15:00  profit=       4,421.17  return=   11.11%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:15:00  profit=         354.22  return=    1.81%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:15:00  profit=          44.86  return=    3.12%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:20:00  profit=      13,661.76  return=   32.33%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:20:00  profit=       6,095.30  return=   17.33%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:20:00  profit=       4,421.17  return=   11.11%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:20:00  profit=         354.22  return=    1.81%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:20:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:25:00  profit=      13,661.76  return=   32.33%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:25:00  profit=       6,095.30  return=   17.33%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:25:00  profit=       4,421.17  return=   11.11%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:25:00  profit=         354.22  return=    1.81%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:25:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:30:00  profit=      13,663.14  return=   32.33%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:30:00  profit=       6,095.30  return=   17.33%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:30:00  profit=       4,421.17  return=   11.11%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:30:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:30:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:35:00  profit=      13,664.19  return=   32.33%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:35:00  profit=       6,095.77  return=   17.33%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:35:00  profit=       4,421.74  return=   11.11%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:35:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:35:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:40:00  profit=      13,664.19  return=   32.33%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:40:00  profit=       6,095.77  return=   17.33%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:40:00  profit=       4,421.74  return=   11.11%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:40:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:40:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:45:00  profit=      13,664.19  return=   32.33%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:45:00  profit=       6,095.77  return=   17.33%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:45:00  profit=       4,421.74  return=   11.11%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:45:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:45:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:50:00  profit=      13,673.59  return=   32.36%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:50:00  profit=       6,100.05  return=   17.35%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:50:00  profit=       4,426.87  return=   11.13%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:50:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:50:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:55:00  profit=      13,673.59  return=   32.36%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:55:00  profit=       6,100.05  return=   17.35%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:55:00  profit=       4,426.87  return=   11.13%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:55:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:55:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:00:00  profit=      13,673.59  return=   32.36%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:00:00  profit=       6,100.05  return=   17.35%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:00:00  profit=       4,426.87  return=   11.13%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:00:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:00:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:05:00  profit=      13,758.34  return=   32.55%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:05:00  profit=       6,138.57  return=   17.45%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:05:00  profit=       4,473.09  return=   11.24%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:05:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:05:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:10:00  profit=      13,798.99  return=   32.65%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:10:00  profit=       6,157.05  return=   17.51%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:10:00  profit=       4,495.27  return=   11.30%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:10:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:10:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:15:00  profit=      13,798.99  return=   32.65%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:15:00  profit=       6,157.05  return=   17.51%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:15:00  profit=       4,495.27  return=   11.30%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:15:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:15:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:20:00  profit=      13,798.99  return=   32.65%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:20:00  profit=       6,157.05  return=   17.51%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:20:00  profit=       4,495.27  return=   11.30%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:20:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:20:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:25:00  profit=      13,798.99  return=   32.65%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:25:00  profit=       6,157.05  return=   17.51%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:25:00  profit=       4,495.27  return=   11.30%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:25:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:25:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:30:00  profit=      13,798.99  return=   32.65%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:30:00  profit=       6,157.05  return=   17.51%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:30:00  profit=       4,495.27  return=   11.30%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:30:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:30:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:35:00  profit=      14,340.20  return=   33.91%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:35:00  profit=       6,499.72  return=   18.47%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:35:00  profit=       4,854.31  return=   12.20%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:35:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:35:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:40:00  profit=      14,340.20  return=   33.91%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:40:00  profit=       6,499.72  return=   18.47%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:40:00  profit=       4,854.31  return=   12.20%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:40:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:40:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:45:00  profit=      14,255.45  return=   33.71%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:45:00  profit=       6,461.20  return=   18.36%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:45:00  profit=       4,808.08  return=   12.08%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:45:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:45:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:50:00  profit=      14,263.24  return=   33.73%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:50:00  profit=       6,468.99  return=   18.39%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:50:00  profit=       4,815.87  return=   12.10%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:50:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:50:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:55:00  profit=      14,342.18  return=   33.92%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:55:00  profit=       6,500.62  return=   18.48%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:55:00  profit=       4,855.39  return=   12.20%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:55:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:55:00  profit=          66.33  return=    1.03%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 05:55:00  profit=          57.45  return=    0.85%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 05:55:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:00:00  profit=      14,342.18  return=   33.92%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:00:00  profit=       6,500.62  return=   18.48%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:00:00  profit=       4,855.39  return=   12.20%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:00:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:00:00  profit=          66.33  return=    1.03%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 06:00:00  profit=          57.45  return=    0.85%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 06:00:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:05:00  profit=      14,342.18  return=   33.92%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:05:00  profit=       6,500.62  return=   18.48%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:05:00  profit=       4,855.39  return=   12.20%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:05:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:05:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:10:00  profit=      14,420.04  return=   34.10%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:10:00  profit=       6,471.55  return=   18.39%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:10:00  profit=       4,818.58  return=   12.11%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:10:00  profit=         365.85  return=    1.87%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:10:00  profit=          51.64  return=    3.53%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:15:00  profit=      14,345.27  return=   33.92%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:15:00  profit=       6,502.71  return=   18.48%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:15:00  profit=       4,857.53  return=   12.20%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:15:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:15:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:20:00  profit=      14,379.99  return=   34.00%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:20:00  profit=       6,524.26  return=   18.54%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:20:00  profit=       4,880.27  return=   12.26%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:20:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:20:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:25:00  profit=      13,763.42  return=   32.57%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:25:00  profit=       6,141.56  return=   17.46%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:25:00  profit=       4,476.31  return=   11.25%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:25:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:25:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:30:00  profit=      13,763.42  return=   32.57%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:30:00  profit=       6,141.56  return=   17.46%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:30:00  profit=       4,476.31  return=   11.25%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:30:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:30:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:35:00  profit=      13,763.52  return=   32.57%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:35:00  profit=       6,141.61  return=   17.46%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:35:00  profit=       4,476.37  return=   11.25%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:35:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:35:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:40:00  profit=      13,763.52  return=   32.57%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:40:00  profit=       6,141.61  return=   17.46%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:40:00  profit=       4,476.37  return=   11.25%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:40:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:40:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:45:00  profit=      13,763.52  return=   32.57%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:45:00  profit=       6,141.61  return=   17.46%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:45:00  profit=       4,476.37  return=   11.25%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:45:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:45:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:45:00  profit=      31,488.15  return=    5.31%  type=Compressed Gelidus
# ArbOpp time=2017-01-10 06:50:00  profit=      13,763.52  return=   32.57%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:50:00  profit=       4,476.37  return=   11.25%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:50:00  profit=         356.16  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:50:00  profit=          22.86  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:50:00  profit=      33,372.00  return=    5.62%  type=Compressed Gelidus
# ArbOpp time=2017-01-10 06:55:00  profit=      14,358.86  return=   33.95%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:55:00  profit=       4,899.08  return=   12.31%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:55:00  profit=         391.05  return=    1.99%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:55:00  profit=          26.56  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 06:55:00  profit=          25.74  return=    1.76%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 07:00:00  profit=      14,358.86  return=   33.95%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:00:00  profit=       4,899.08  return=   12.31%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:00:00  profit=         391.05  return=    1.99%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:00:00  profit=          26.56  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:00:00  profit=          25.74  return=    1.76%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 07:05:00  profit=      14,358.86  return=   33.95%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:05:00  profit=       4,899.08  return=   12.31%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:05:00  profit=         391.05  return=    1.99%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:05:00  profit=          26.56  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:05:00  profit=          25.74  return=    1.76%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 07:10:00  profit=      14,358.86  return=   33.95%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:10:00  profit=       4,899.08  return=   12.31%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:10:00  profit=         391.05  return=    1.99%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:10:00  profit=          26.56  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:10:00  profit=          25.74  return=    1.76%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 07:15:00  profit=      14,328.32  return=   33.88%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:15:00  profit=       4,899.08  return=   12.31%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:15:00  profit=         389.11  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:15:00  profit=          25.00  return=    0.37%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:15:00  profit=          19.98  return=    1.37%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 07:20:00  profit=      14,328.32  return=   33.88%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:20:00  profit=       4,899.08  return=   12.31%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:20:00  profit=         389.11  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:20:00  profit=          25.00  return=    0.37%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:20:00  profit=          19.98  return=    1.37%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 07:25:00  profit=      14,328.32  return=   33.88%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:25:00  profit=       4,899.08  return=   12.31%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:25:00  profit=         389.11  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:25:00  profit=          25.00  return=    0.37%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:30:00  profit=      14,328.32  return=   33.88%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:30:00  profit=       4,899.08  return=   12.31%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:30:00  profit=         389.11  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:30:00  profit=          26.00  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:35:00  profit=      14,328.32  return=   33.88%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:35:00  profit=       4,899.08  return=   12.31%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:35:00  profit=         389.11  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:35:00  profit=          26.00  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:40:00  profit=      15,797.31  return=   37.30%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:40:00  profit=         262.62  return=    0.62%  type=Pure Jaspet
# ArbOpp time=2017-01-10 07:40:00  profit=       6,147.67  return=   15.42%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:40:00  profit=       1,073.11  return=    5.46%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:40:00  profit=         228.54  return=    3.37%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:45:00  profit=      15,797.31  return=   37.30%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:45:00  profit=         262.62  return=    0.62%  type=Pure Jaspet
# ArbOpp time=2017-01-10 07:45:00  profit=       6,147.67  return=   15.42%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:45:00  profit=         788.05  return=    4.14%  type=Luminous Kernite
# ArbOpp time=2017-01-10 07:45:00  profit=       1,073.11  return=    5.46%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:45:00  profit=         228.54  return=    3.37%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:50:00  profit=      14,328.32  return=   33.88%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:50:00  profit=       4,899.08  return=   12.31%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:50:00  profit=         125.81  return=    0.66%  type=Luminous Kernite
# ArbOpp time=2017-01-10 07:50:00  profit=         389.11  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:50:00  profit=          26.00  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:55:00  profit=      14,328.32  return=   33.88%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:55:00  profit=       4,899.08  return=   12.31%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:55:00  profit=         125.81  return=    0.66%  type=Luminous Kernite
# ArbOpp time=2017-01-10 07:55:00  profit=         389.11  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:55:00  profit=          26.00  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:00:00  profit=       4,350.58  return=    8.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 08:00:00  profit=          26.00  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:05:00  profit=       4,350.58  return=    8.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 08:05:00  profit=          26.00  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:10:00  profit=       4,350.58  return=    8.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 08:10:00  profit=          26.00  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:15:00  profit=       4,350.58  return=    8.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 08:15:00  profit=          26.00  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:20:00  profit=       4,350.58  return=    8.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 08:20:00  profit=          26.00  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:25:00  profit=       4,352.66  return=    8.32%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 08:25:00  profit=          30.68  return=    0.45%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:30:00  profit=          33.77  return=    0.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:35:00  profit=          33.77  return=    0.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:40:00  profit=          33.77  return=    0.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:45:00  profit=          33.77  return=    0.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:50:00  profit=          33.77  return=    0.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:55:00  profit=          33.77  return=    0.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:00:00  profit=          40.76  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:05:00  profit=          40.76  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:10:00  profit=          40.76  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:15:00  profit=          40.76  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:20:00  profit=          40.76  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:25:00  profit=          40.76  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:30:00  profit=          40.76  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:35:00  profit=          40.76  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:40:00  profit=          40.76  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:45:00  profit=          40.76  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:50:00  profit=          45.40  return=    0.67%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:55:00  profit=          46.18  return=    0.68%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:00:00  profit=          46.18  return=    0.68%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:05:00  profit=          22.04  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:10:00  profit=          22.04  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:15:00  profit=          22.04  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:20:00  profit=          22.04  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:25:00  profit=          22.04  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:30:00  profit=          22.04  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:35:00  profit=          22.04  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:40:00  profit=          22.04  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:40:00  profit=       1,287.35  return=    0.99%  type=Gneiss
# ArbOpp time=2017-01-10 10:45:00  profit=         120.04  return=    1.80%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:45:00  profit=       1,287.35  return=    0.99%  type=Gneiss
# ArbOpp time=2017-01-10 10:50:00  profit=         120.82  return=    1.81%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:50:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 10:55:00  profit=          44.13  return=    0.66%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 10:55:00  profit=         365.43  return=    5.47%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:55:00  profit=       6,123.27  return=    4.72%  type=Gneiss
# ArbOpp time=2017-01-10 10:55:00  profit=       3,046.78  return=    2.08%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 11:00:00  profit=         128.61  return=    1.93%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:00:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:05:00  profit=         128.61  return=    1.93%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:05:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:10:00  profit=         128.61  return=    1.93%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:10:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:15:00  profit=         128.61  return=    1.93%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:15:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:20:00  profit=         128.61  return=    1.93%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:20:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:25:00  profit=         120.82  return=    1.81%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:25:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:30:00  profit=         120.82  return=    1.81%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:30:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:35:00  profit=      10,075.25  return=    1.89%  type=Bistot
# ArbOpp time=2017-01-10 11:35:00  profit=          32.46  return=    0.50%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 11:35:00  profit=         120.82  return=    1.81%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:35:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:40:00  profit=      10,075.25  return=    1.89%  type=Bistot
# ArbOpp time=2017-01-10 11:40:00  profit=          32.46  return=    0.50%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 11:40:00  profit=         120.82  return=    1.81%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:40:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:45:00  profit=      10,075.25  return=    1.89%  type=Bistot
# ArbOpp time=2017-01-10 11:45:00  profit=          32.46  return=    0.50%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 11:45:00  profit=         120.82  return=    1.81%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:45:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:50:00  profit=      10,075.25  return=    1.89%  type=Bistot
# ArbOpp time=2017-01-10 11:50:00  profit=          32.46  return=    0.50%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 11:50:00  profit=         120.82  return=    1.81%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:50:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:55:00  profit=      10,075.25  return=    1.89%  type=Bistot
# ArbOpp time=2017-01-10 11:55:00  profit=          32.46  return=    0.50%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 11:55:00  profit=         120.82  return=    1.81%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:55:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:00:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:00:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:05:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:05:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:10:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:10:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:15:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:15:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:20:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:20:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:25:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:25:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:30:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:30:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:35:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:35:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:40:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:40:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:45:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:45:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:50:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:50:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:55:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:55:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:00:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:00:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:05:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:05:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:10:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:10:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:15:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:15:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:20:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:20:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:25:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:25:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:30:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:30:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:35:00  profit=          22.82  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:35:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:40:00  profit=          23.60  return=    0.35%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:40:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:45:00  profit=          25.15  return=    0.37%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:45:00  profit=       1,321.69  return=    1.02%  type=Gneiss
# ArbOpp time=2017-01-10 13:50:00  profit=         491.15  return=    7.79%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:50:00  profit=       1,323.66  return=    1.02%  type=Gneiss
# ArbOpp time=2017-01-10 13:55:00  profit=          37.59  return=    0.56%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:55:00  profit=       1,543.00  return=    1.19%  type=Gneiss
# ArbOpp time=2017-01-10 14:00:00  profit=         141.51  return=    2.19%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:00:00  profit=         166.91  return=    2.46%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:00:00  profit=       4,175.01  return=    3.22%  type=Gneiss
# ArbOpp time=2017-01-10 14:00:00  profit=         903.58  return=    0.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:05:00  profit=         137.83  return=    2.13%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:05:00  profit=         163.03  return=    2.41%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:05:00  profit=       4,145.94  return=    3.20%  type=Gneiss
# ArbOpp time=2017-01-10 14:05:00  profit=         871.60  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:10:00  profit=         147.79  return=    2.29%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:10:00  profit=         166.15  return=    2.45%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:10:00  profit=       4,209.37  return=    3.25%  type=Gneiss
# ArbOpp time=2017-01-10 14:10:00  profit=         941.37  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:15:00  profit=         144.83  return=    2.24%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:15:00  profit=         163.03  return=    2.41%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:15:00  profit=       4,145.94  return=    3.20%  type=Gneiss
# ArbOpp time=2017-01-10 14:15:00  profit=         871.60  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:20:00  profit=         144.83  return=    2.24%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:20:00  profit=         163.03  return=    2.41%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:20:00  profit=       4,147.92  return=    3.20%  type=Gneiss
# ArbOpp time=2017-01-10 14:20:00  profit=         873.78  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:25:00  profit=         145.57  return=    2.25%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:25:00  profit=         163.81  return=    2.42%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:25:00  profit=       8,349.65  return=    6.66%  type=Gneiss
# ArbOpp time=2017-01-10 14:25:00  profit=         875.96  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:30:00  profit=         145.57  return=    2.25%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:30:00  profit=         163.81  return=    2.42%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:30:00  profit=       8,349.65  return=    6.66%  type=Gneiss
# ArbOpp time=2017-01-10 14:30:00  profit=         875.96  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:35:00  profit=         149.25  return=    2.31%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:35:00  profit=         167.69  return=    2.47%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:35:00  profit=       8,378.72  return=    6.68%  type=Gneiss
# ArbOpp time=2017-01-10 14:35:00  profit=         907.93  return=    0.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:40:00  profit=         149.25  return=    2.31%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:40:00  profit=         169.69  return=    2.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:40:00  profit=       8,378.72  return=    6.68%  type=Gneiss
# ArbOpp time=2017-01-10 14:40:00  profit=         907.93  return=    0.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:45:00  profit=         149.25  return=    2.31%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:45:00  profit=         169.69  return=    2.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:45:00  profit=       8,378.72  return=    6.68%  type=Gneiss
# ArbOpp time=2017-01-10 14:45:00  profit=         907.93  return=    0.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:50:00  profit=         150.73  return=    2.33%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:50:00  profit=         171.24  return=    2.53%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:50:00  profit=       8,395.24  return=    6.69%  type=Gneiss
# ArbOpp time=2017-01-10 14:50:00  profit=         926.10  return=    0.63%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:55:00  profit=         150.73  return=    2.33%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:55:00  profit=         171.24  return=    2.53%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:55:00  profit=       8,395.24  return=    6.69%  type=Gneiss
# ArbOpp time=2017-01-10 14:55:00  profit=         926.10  return=    0.63%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:00:00  profit=         149.99  return=    2.32%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 15:00:00  profit=         170.46  return=    2.52%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 15:00:00  profit=       8,393.26  return=    6.69%  type=Gneiss
# ArbOpp time=2017-01-10 15:00:00  profit=         923.92  return=    0.63%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:05:00  profit=         149.99  return=    2.32%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 15:05:00  profit=         170.46  return=    2.52%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 15:05:00  profit=       9,742.87  return=    7.77%  type=Gneiss
# ArbOpp time=2017-01-10 15:05:00  profit=       2,409.79  return=    1.65%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:10:00  profit=         170.46  return=    2.52%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 15:10:00  profit=       8,393.26  return=    6.69%  type=Gneiss
# ArbOpp time=2017-01-10 15:10:00  profit=         923.92  return=    0.63%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:15:00  profit=         172.00  return=    2.54%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 15:15:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:15:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:20:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:20:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:25:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:25:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:30:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:30:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:35:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:35:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:40:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:40:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:45:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:45:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:50:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:50:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:55:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:55:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:00:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 16:00:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:05:00  profit=       8,509.77  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:05:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:10:00  profit=       8,509.77  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:10:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:15:00  profit=       8,509.77  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:15:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:20:00  profit=       8,509.77  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:20:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:25:00  profit=       8,509.77  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:25:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:30:00  profit=       8,509.77  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:30:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:35:00  profit=       8,509.77  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:35:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:40:00  profit=       8,509.77  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:40:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:45:00  profit=       8,530.23  return=    6.81%  type=Gneiss
# ArbOpp time=2017-01-10 16:45:00  profit=         964.60  return=    0.66%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:50:00  profit=       8,530.23  return=    6.81%  type=Gneiss
# ArbOpp time=2017-01-10 16:50:00  profit=         964.60  return=    0.66%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:55:00  profit=       8,495.24  return=    6.78%  type=Gneiss
# ArbOpp time=2017-01-10 16:55:00  profit=         926.10  return=    0.63%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:00:00  profit=       8,451.63  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 17:00:00  profit=         878.13  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:05:00  profit=           0.24  return=    0.02%  type=Compressed Dense Veldspar
# ArbOpp time=2017-01-10 17:05:00  profit=       8,524.31  return=    6.80%  type=Gneiss
# ArbOpp time=2017-01-10 17:05:00  profit=         958.07  return=    0.65%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:10:00  profit=           0.24  return=    0.02%  type=Compressed Dense Veldspar
# ArbOpp time=2017-01-10 17:10:00  profit=       9,773.09  return=    7.80%  type=Gneiss
# ArbOpp time=2017-01-10 17:10:00  profit=       2,331.96  return=    1.59%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:15:00  profit=           0.24  return=    0.02%  type=Compressed Dense Veldspar
# ArbOpp time=2017-01-10 17:15:00  profit=       9,773.09  return=    7.80%  type=Gneiss
# ArbOpp time=2017-01-10 17:15:00  profit=       2,331.96  return=    1.59%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:20:00  profit=       9,802.16  return=    7.82%  type=Gneiss
# ArbOpp time=2017-01-10 17:20:00  profit=       2,363.94  return=    1.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:25:00  profit=       9,802.16  return=    7.82%  type=Gneiss
# ArbOpp time=2017-01-10 17:25:00  profit=       2,363.94  return=    1.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:30:00  profit=       9,773.09  return=    7.80%  type=Gneiss
# ArbOpp time=2017-01-10 17:30:00  profit=       2,331.96  return=    1.59%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:35:00  profit=       9,773.09  return=    7.80%  type=Gneiss
# ArbOpp time=2017-01-10 17:35:00  profit=       2,331.96  return=    1.59%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:40:00  profit=      12,325.83  return=    9.82%  type=Gneiss
# ArbOpp time=2017-01-10 17:40:00  profit=       5,140.13  return=    3.51%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:45:00  profit=       8,453.61  return=    6.75%  type=Gneiss
# ArbOpp time=2017-01-10 17:45:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:50:00  profit=       8,453.61  return=    6.75%  type=Gneiss
# ArbOpp time=2017-01-10 17:50:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:55:00  profit=       8,453.61  return=    6.75%  type=Gneiss
# ArbOpp time=2017-01-10 17:55:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:00:00  profit=       8,453.61  return=    6.75%  type=Gneiss
# ArbOpp time=2017-01-10 18:00:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:05:00  profit=       8,453.61  return=    6.75%  type=Gneiss
# ArbOpp time=2017-01-10 18:05:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:10:00  profit=       8,453.61  return=    6.75%  type=Gneiss
# ArbOpp time=2017-01-10 18:10:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:15:00  profit=       8,453.61  return=    6.75%  type=Gneiss
# ArbOpp time=2017-01-10 18:15:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:20:00  profit=       8,453.61  return=    6.75%  type=Gneiss
# ArbOpp time=2017-01-10 18:20:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:25:00  profit=       8,451.63  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 18:25:00  profit=         878.13  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:30:00  profit=       8,451.63  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 18:30:00  profit=         878.13  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:35:00  profit=       8,452.63  return=    6.75%  type=Gneiss
# ArbOpp time=2017-01-10 18:35:00  profit=         878.13  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:40:00  profit=       8,452.63  return=    6.75%  type=Gneiss
# ArbOpp time=2017-01-10 18:40:00  profit=         878.13  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:45:00  profit=         639.94  return=   10.14%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 18:45:00  profit=       8,500.20  return=    6.78%  type=Gneiss
# ArbOpp time=2017-01-10 18:45:00  profit=         930.46  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:50:00  profit=       8,500.20  return=    6.78%  type=Gneiss
# ArbOpp time=2017-01-10 18:50:00  profit=         930.46  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:55:00  profit=       8,547.76  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 18:55:00  profit=         982.78  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:00:00  profit=       8,547.76  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 19:00:00  profit=         982.78  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:05:00  profit=       8,547.76  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 19:05:00  profit=         982.78  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:10:00  profit=       8,547.76  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 19:10:00  profit=         982.78  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:15:00  profit=       8,579.48  return=    6.85%  type=Gneiss
# ArbOpp time=2017-01-10 19:15:00  profit=       1,017.67  return=    0.70%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:20:00  profit=       2,550.28  return=    4.26%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 19:20:00  profit=          94.29  return=    1.32%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 19:20:00  profit=      13,614.42  return=   10.85%  type=Gneiss
# ArbOpp time=2017-01-10 19:20:00  profit=       6,556.93  return=    4.48%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:25:00  profit=          25.29  return=    0.36%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 19:25:00  profit=      12,475.25  return=    9.94%  type=Gneiss
# ArbOpp time=2017-01-10 19:25:00  profit=       5,303.27  return=    3.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:30:00  profit=       8,590.66  return=    6.86%  type=Gneiss
# ArbOpp time=2017-01-10 19:30:00  profit=       1,029.98  return=    0.70%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:35:00  profit=       8,543.09  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 19:35:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:40:00  profit=       8,543.09  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 19:40:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:45:00  profit=       8,543.09  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 19:45:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:50:00  profit=       8,543.09  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 19:50:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:55:00  profit=       8,558.95  return=    6.83%  type=Gneiss
# ArbOpp time=2017-01-10 19:55:00  profit=         995.10  return=    0.68%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:00:00  profit=       8,558.95  return=    6.83%  type=Gneiss
# ArbOpp time=2017-01-10 20:00:00  profit=         995.10  return=    0.68%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:05:00  profit=       1,766.43  return=    3.26%  type=Vitric Hedbergite
# ArbOpp time=2017-01-10 20:05:00  profit=       4,633.79  return=    8.52%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 20:05:00  profit=       8,579.41  return=    6.85%  type=Gneiss
# ArbOpp time=2017-01-10 20:05:00  profit=       1,017.61  return=    0.70%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:10:00  profit=       4,641.01  return=    8.53%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 20:10:00  profit=       8,580.41  return=    6.85%  type=Gneiss
# ArbOpp time=2017-01-10 20:10:00  profit=       1,017.61  return=    0.70%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:15:00  profit=       4,921.14  return=    9.05%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 20:15:00  profit=       9,896.41  return=    7.89%  type=Gneiss
# ArbOpp time=2017-01-10 20:15:00  profit=       2,465.30  return=    1.68%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:20:00  profit=         112.31  return=    2.29%  type=Viscous Pyroxeres
# ArbOpp time=2017-01-10 20:20:00  profit=       9,896.41  return=    7.89%  type=Gneiss
# ArbOpp time=2017-01-10 20:20:00  profit=       2,465.30  return=    1.68%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:25:00  profit=          65.65  return=    1.34%  type=Viscous Pyroxeres
# ArbOpp time=2017-01-10 20:25:00  profit=       8,550.02  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:25:00  profit=         984.18  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:30:00  profit=          65.65  return=    1.34%  type=Viscous Pyroxeres
# ArbOpp time=2017-01-10 20:30:00  profit=       8,544.09  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:30:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:35:00  profit=       8,544.09  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:35:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:40:00  profit=       8,544.09  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:40:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:45:00  profit=       8,544.09  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:45:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:50:00  profit=       8,544.09  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:50:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:55:00  profit=       8,544.09  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:55:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 21:00:00  profit=       8,544.09  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 21:00:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 21:05:00  profit=       5,721.81  return=    4.57%  type=Gneiss
# ArbOpp time=2017-01-10 21:10:00  profit=       5,721.81  return=    4.57%  type=Gneiss
# ArbOpp time=2017-01-10 21:15:00  profit=       5,819.81  return=    4.65%  type=Gneiss
# ArbOpp time=2017-01-10 21:20:00  profit=       2,566.22  return=    4.29%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 21:20:00  profit=       1,200.85  return=    2.59%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 21:20:00  profit=         144.92  return=    2.03%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 21:20:00  profit=          40.76  return=    2.77%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 21:20:00  profit=      14,728.78  return=   11.74%  type=Gneiss
# ArbOpp time=2017-01-10 21:20:00  profit=       7,673.90  return=    5.24%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 21:25:00  profit=       2,566.22  return=    4.29%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 21:25:00  profit=       1,200.85  return=    2.59%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 21:25:00  profit=         144.92  return=    2.03%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 21:25:00  profit=          40.76  return=    2.77%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 21:25:00  profit=      14,728.78  return=   11.74%  type=Gneiss
# ArbOpp time=2017-01-10 21:25:00  profit=       7,673.90  return=    5.24%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 21:30:00  profit=       5,819.81  return=    4.65%  type=Gneiss
# ArbOpp time=2017-01-10 21:35:00  profit=       5,819.81  return=    4.65%  type=Gneiss
# ArbOpp time=2017-01-10 21:40:00  profit=       5,819.81  return=    4.65%  type=Gneiss
# ArbOpp time=2017-01-10 21:45:00  profit=       5,819.81  return=    4.65%  type=Gneiss
# ArbOpp time=2017-01-10 21:50:00  profit=       5,819.81  return=    4.65%  type=Gneiss
# ArbOpp time=2017-01-10 21:55:00  profit=       5,819.81  return=    4.65%  type=Gneiss
# ArbOpp time=2017-01-10 22:00:00  profit=       5,819.81  return=    4.65%  type=Gneiss
# ArbOpp time=2017-01-10 22:05:00  profit=       6,136.92  return=    4.91%  type=Gneiss
# ArbOpp time=2017-01-10 22:10:00  profit=       6,136.92  return=    4.91%  type=Gneiss
# ArbOpp time=2017-01-10 22:15:00  profit=       6,215.49  return=    4.97%  type=Gneiss
# ArbOpp time=2017-01-10 22:20:00  profit=       6,275.60  return=    5.02%  type=Gneiss
# ArbOpp time=2017-01-10 22:25:00  profit=       5,868.64  return=    4.69%  type=Gneiss
# ArbOpp time=2017-01-10 22:30:00  profit=       5,868.64  return=    4.69%  type=Gneiss
# ArbOpp time=2017-01-10 22:35:00  profit=       3,797.71  return=    6.99%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 22:35:00  profit=       5,868.64  return=    4.69%  type=Gneiss
# ArbOpp time=2017-01-10 22:40:00  profit=       4,662.07  return=    8.57%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 22:40:00  profit=       5,870.62  return=    4.69%  type=Gneiss
# ArbOpp time=2017-01-10 22:45:00  profit=       4,663.52  return=    8.58%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 22:45:00  profit=       5,872.59  return=    4.69%  type=Gneiss
# ArbOpp time=2017-01-10 22:50:00  profit=       4,663.52  return=    8.58%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 22:50:00  profit=       5,856.74  return=    4.68%  type=Gneiss
# ArbOpp time=2017-01-10 22:55:00  profit=       4,676.71  return=    8.60%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 22:55:00  profit=       5,873.25  return=    4.70%  type=Gneiss
# ArbOpp time=2017-01-10 23:00:00  profit=       4,685.56  return=    8.62%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 23:00:00  profit=       5,889.76  return=    4.71%  type=Gneiss
# ArbOpp time=2017-01-10 23:05:00  profit=       4,685.56  return=    8.62%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 23:05:00  profit=       5,889.76  return=    4.71%  type=Gneiss
# ArbOpp time=2017-01-10 23:10:00  profit=       4,685.56  return=    8.62%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 23:10:00  profit=       5,889.76  return=    4.71%  type=Gneiss
# ArbOpp time=2017-01-10 23:15:00  profit=       4,685.56  return=    8.62%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 23:15:00  profit=       5,890.76  return=    4.71%  type=Gneiss
# ArbOpp time=2017-01-10 23:20:00  profit=       4,685.56  return=    8.62%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 23:20:00  profit=       5,890.76  return=    4.71%  type=Gneiss
# ArbOpp time=2017-01-10 23:25:00  profit=       4,687.27  return=    8.62%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 23:25:00  profit=       5,890.76  return=    4.71%  type=Gneiss
# ArbOpp time=2017-01-10 23:30:00  profit=       5,890.76  return=    4.71%  type=Gneiss
# ArbOpp time=2017-01-10 23:35:00  profit=       5,906.61  return=    4.72%  type=Gneiss
# ArbOpp time=2017-01-10 23:40:00  profit=       5,854.40  return=    4.68%  type=Gneiss
# ArbOpp time=2017-01-10 23:45:00  profit=       5,870.26  return=    4.69%  type=Gneiss
# ArbOpp time=2017-01-10 23:50:00  profit=       5,876.19  return=    4.70%  type=Gneiss
# ArbOpp time=2017-01-10 23:55:00  profit=       5,876.19  return=    4.70%  type=Gneiss
# Total opportunities: 669

# %%
# There seem to be ample arbitrage opportunities on our sample day.  To capture the full potential 
# of an opportunity, we need to continue to buy and refine source assets until it is no longer
# profitable to do so.  This requires that we track the state of buy and sell orders during
# each round of processing an opportunity.  We can implement this tracking by extracting order
# lists from each snapshot, and updating volume as we consume orders.  We'll implement new
# versions of our buyer and seller functions to handle this tracking.

# The new version of our asset buyer will attempt to buy from a list of orders which are
# assumed to already be filtered to sell orders of the given type and the appropriate
# location.  This function will consume orders to fill the given volume, and will return
# a list of objects {price, volume} showing the orders that were made.  This list will
# be empty if we can not fill the order completely.
def attempt_buy_type_list(buy_volume, sell_order_list):
    potential = []
    for next_order in sell_order_list:
        if buy_volume >= next_order['min_volume'] and next_order['volume'] > 0:
            # Buy into this order
            amount = min(buy_volume, next_order['volume'])
            order_record = dict(price=next_order['price'], volume=amount)
            buy_volume -= amount
            next_order['volume'] -= amount
            potential.append(order_record)
        if buy_volume == 0:
            # We've completely filled this order
            return potential
    # If we never completely fill the order then return no orders
    return []

# %%
# The new version of our asset seller will attempt to sell to a list of orders which
# are assumed to already be filtered to buy orders of the given type.  We use our
# range checker to implement proper ranged buy order matching.  This function will 
# consume volume from an order if possible, and return a list of objects {price, volume} 
# showing the orders that were filled.  This list will be empty if we can not fill
# the order completely.
def attempt_sell_type_list(sell_region_id, sell_location_id, sell_volume, buy_order_list):
    config = dict(use_citadel=False)
    potential = []
    for next_order in buy_order_list:
        try:
            if sell_volume >= next_order['min_volume'] and next_order['volume'] > 0 and \
               TradingUtil.check_range(sell_region_id, sell_location_id, next_order['location_id'], 
                                       next_order['order_range'], config):
                # Sell into this order
                amount = min(sell_volume, next_order['volume'])
                order_record = dict(price=next_order['price'], volume=amount)
                sell_volume -= amount
                next_order['volume'] -= amount
                potential.append(order_record)
        except:
            # We'll get an exception if TradingUtil can't find the location of a player-owned
            # station.  We'll ignore those for now.  Change "use_citadeL" to True above
            # if you'd like to attempt to resolve the location of these stations from a 
            # third party source.
            pass
        if sell_volume == 0:
            # We've completely filled this order
            return potential
    # If we never completely fill the order then return no orders
    return []

# %%
# We'll include a few other convenience functions to simplify our implementation

# This function extracts sell orders from a snapshot based on type and station ID.
# Recall that sell orders are sorted low price to high price in the DataFrame.
def extract_sell_orders(snapshot, type_id, station_id):
    by_type = snapshot[snapshot.type_id == type_id]
    by_loc = by_type[by_type.location_id == station_id]
    by_side = by_loc[by_loc.buy == False]
    return [next_order[1] for next_order in by_side.iterrows()]

# This function extracts buy orders from a snapshot based on type ID.
# Recall that buy orders are sorted high price to low price in the DataFrame.
def extract_buy_orders(snapshot, type_id):
    by_type = snapshot[snapshot.type_id == type_id]
    by_side = by_type[by_type.buy == True]
    return [next_order[1] for next_order in by_side.iterrows()]

# This function will combine orders by price so that the resulting
# list has one entry for each price, with the total volume filled at
# that price.  This compression simplifies the display of orders in
# our output functions.
def compress_order_list(order_list, ascending=True):
    order_map = {}
    for next_order in order_list:
        if next_order['price'] not in order_map:
            order_map[next_order['price']] = next_order['volume']
        else:
            order_map[next_order['price']] += next_order['volume']
    orders = [ dict(price=k,volume=v) for k, v in order_map.items()]
    return sorted(orders, key=lambda x: x['price'], reverse=not ascending)

# %%
# Now we can write a function that attempts to consume all opportunities for a single type
# in a given snapshot.  This function will attempt to buy and refine as long as it is profitable 
# to do so.  The result of this function will be None if no opportunity was available, or an object:
#
# {
#   gross: gross proceeds (total of all sales)
#   cost: total cost (cost of buying source plus refinement costs)
#   profit: gross - cost
#   margin: cost / profit
#   buy_orders: the compressed list of buy orders that were placed
#   sell_orders: map from material type ID to the compressed list of sell orders that were placed
# }
#
# Compressed order lists group orders by price and sum the volume.
#
def attempt_opportunity(snapshot, type_id, region_id, station_id, type_map, tax_rate, efficiency, station_tax):
    # Reduce to type to extract minimum reprocessing volume
    by_type = snapshot[snapshot.type_id == type_id]
    required_volume = type_map[type_id]['portionSize']
    #
    # Create source sell order list.
    sell_order_list = extract_sell_orders(snapshot, type_id, station_id)
    #
    # Create refined materials buy order lists.
    buy_order_map = {}
    all_sell_orders = {}
    for next_mat in type_map[type_id]['material_map'].values():
        mat_type_id = next_mat['materialTypeID']
        buy_order_map[mat_type_id] = extract_buy_orders(snapshot, mat_type_id)
        all_sell_orders[mat_type_id] = []
    #
    # Now iterate through sell orders until we stop making a profit
    all_buy_orders = []
    gross = 0
    cost = 0
    while True:
        #
        # Attempt to buy source material
        current_cost = 0
        current_gross = 0
        bought = attempt_buy_type_list(required_volume, sell_order_list)
        if len(bought) == 0:
            # Can't buy any more source material, done with this opportunity
            break
        #
        # Add cost of buying source material
        current_cost = np.sum([ x['price'] * x['volume'] for x in bought ])
        #
        # Now attempt to refine and sell all refined materials
        sell_orders = {}
        for next_mat_id in buy_order_map.keys():
            sell_volume = int(type_map[type_id]['material_map'][next_mat_id]['quantity'] * efficiency)
            sold = attempt_sell_type_list(region_id, station_id, sell_volume, buy_order_map[next_mat_id])
            if len(sold) == 0:
                # Can't sell any more refined material, done with this opportunity
                sell_orders = []
                break
            #
            # Add gross profit from selling refined material
            current_gross += (1 - tax_rate) * np.sum([ x['price'] * x['volume'] for x in sold ])
            #
            # Add incremental cost of refining source to this refined material.
            # If we had actual adjusted_prices, we'd use those prices in place of x['price'] below.
            current_cost += station_tax * np.sum([ x['price'] * x['volume'] for x in sold ])
            #
            # Save the set of sale orders we just made
            sell_orders[next_mat_id] = sold
        #
        if len(sell_orders) == 0:
            # We couldn't sell all refined material, so we're done with this opportunity
            break
        #
        # Check whether we've made a profit this round.  If so, record the amounts and continue
        if current_gross > current_cost:
            all_buy_orders.extend(bought)
            for i in sell_orders.keys():
                all_sell_orders[i].extend(sell_orders[i])
            cost += current_cost
            gross += current_gross
        else:
            # This round didn't make any profit so we're done with this opportunity
            break
    #
    # If we were able to make any profit, then report the opportunity
    if gross > cost:
        for i in all_sell_orders.keys():
            all_sell_orders[i]=compress_order_list(all_sell_orders[i], False)
        return dict(gross=gross, cost=cost, profit=gross - cost, margin=(gross - cost)/cost, 
                    buy_orders=compress_order_list(all_buy_orders), 
                    sell_orders=all_sell_orders)
    return None

# %%
# Finally, we can write the complete opportunity finder function
def find_opportunities(order_book, type_map, station_id, region_id, efficiency, sales_tax, station_tax, verbose=False):
    total_snapshots = len(order_book.groupby(order_book.index))
    if verbose:
        print("Checking %d snapshots for opportunities" % total_snapshots)
    opportunities = []
    count = 0
    for snapshot_group in order_book.groupby(order_book.index):
        #
        # Each group is a pair (snapshot_time, snapshot_dataframe)
        snapshot_time = snapshot_group[0]
        snapshot = snapshot_group[1]
        if verbose:
            print("X", end='')
            count += 1
            if count % 72 == 0:
                print()
        #
        # Iterate through each source type looking for opportunities
        for source_type in type_map.values():
            opp = attempt_opportunity(snapshot, source_type['typeID'], region_id, station_id, type_map, 
                                      sales_tax, efficiency, station_tax)
            if opp is not None:
                #
                # Save the time and type if we've found a valid opportunity
                opp['time'] = snapshot_time
                opp['type'] = source_type['typeName']
                opportunities.append(opp)
    if verbose:
        print()
    return opportunities

# %%
#
# NOTE: since this cell attempts to capture complete opportunities, execution will take much longer
# than our earlier cell since that cell only attempted to discover whether an opportunity existed.
#
full_opportunities = find_opportunities(order_book, source_types, station_id, region_id, 
                                        efficiency, tax_rate, station_tax, verbose=True)
# Out:
# Checking 288 snapshots for opportunities
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
# We should have the same number of opportunities as before, but the profit should indicate the
# maximum value achievable from each opportunity.  Here are the results.
display_opportunities(full_opportunities)
# Out:
# ArbOpp time=2017-01-10 00:50:00  profit=  17,105,026.82  return=    1.98%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 00:50:00  profit=  14,630,218.82  return=    0.29%  type=Compressed Bright Spodumain
# ArbOpp time=2017-01-10 00:55:00  profit=  17,105,026.82  return=    1.98%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 00:55:00  profit=  14,614,201.49  return=    0.29%  type=Compressed Bright Spodumain
# ArbOpp time=2017-01-10 01:00:00  profit=  17,105,026.82  return=    1.98%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 01:05:00  profit=  17,106,129.48  return=    1.98%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 01:05:00  profit=          21.02  return=    0.00%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 01:10:00  profit=  17,130,187.58  return=    1.98%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 01:10:00  profit=         482.88  return=    0.01%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 01:15:00  profit=  17,716,597.30  return=    2.05%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 01:15:00  profit=         482.88  return=    0.01%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 02:10:00  profit=         360.84  return=    0.04%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 02:15:00  profit=         360.84  return=    0.04%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 02:55:00  profit=   8,845,325.06  return=    0.61%  type=Compressed Monoclinic Bistot
# ArbOpp time=2017-01-10 03:00:00  profit=   8,706,792.82  return=    0.60%  type=Compressed Monoclinic Bistot
# ArbOpp time=2017-01-10 03:15:00  profit=      19,352.71  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:20:00  profit=      19,352.71  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:25:00  profit=      19,352.71  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:30:00  profit=     203,293.25  return=   31.99%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 03:30:00  profit=      19,352.71  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:35:00  profit=     203,293.25  return=   31.99%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 03:35:00  profit=      19,352.71  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:40:00  profit=     203,297.95  return=   31.99%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 03:40:00  profit=      19,360.57  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:45:00  profit=     203,297.95  return=   31.99%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 03:45:00  profit=      19,360.57  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:50:00  profit=     203,297.95  return=   31.99%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 03:50:00  profit=      19,360.57  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:55:00  profit=     203,297.95  return=   31.99%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 03:55:00  profit=      19,360.57  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:00:00  profit=     418,029.19  return=   11.24%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:00:00  profit=      19,360.57  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:05:00  profit=     418,103.71  return=   11.24%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:05:00  profit=     193,516.46  return=   17.17%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:05:00  profit=     505,684.27  return=    7.91%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:05:00  profit=      71,710.56  return=    1.80%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:10:00  profit=     418,155.03  return=   11.24%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:10:00  profit=     193,516.46  return=   17.17%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:10:00  profit=     505,684.27  return=    7.91%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:10:00  profit=      71,907.27  return=    1.81%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:10:00  profit=     359,443.15  return=    3.12%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:15:00  profit=     418,170.50  return=   11.24%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:15:00  profit=     193,519.50  return=   17.17%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:15:00  profit=     505,702.05  return=    7.91%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:15:00  profit=      71,907.27  return=    1.81%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:15:00  profit=     359,443.15  return=    3.12%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:20:00  profit=     418,170.50  return=   11.24%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:20:00  profit=     193,519.50  return=   17.17%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:20:00  profit=     505,702.05  return=    7.91%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:20:00  profit=      71,907.27  return=    1.81%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:20:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:25:00  profit=     418,170.50  return=   11.24%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:25:00  profit=     193,519.50  return=   17.17%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:25:00  profit=     505,702.05  return=    7.91%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:25:00  profit=      71,907.27  return=    1.81%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:25:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:30:00  profit=     418,273.14  return=   11.24%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:30:00  profit=     193,519.50  return=   17.17%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:30:00  profit=     505,702.05  return=    7.91%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:30:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:30:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:35:00  profit=     418,350.47  return=   11.25%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:35:00  profit=     193,534.70  return=   17.17%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:35:00  profit=     505,790.97  return=    7.91%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:35:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:35:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:40:00  profit=     418,350.47  return=   11.25%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:40:00  profit=     193,534.70  return=   17.17%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:40:00  profit=     505,790.97  return=    7.91%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:40:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:40:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:45:00  profit=     418,350.47  return=   11.25%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:45:00  profit=     193,534.70  return=   17.17%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:45:00  profit=     505,790.97  return=    7.91%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:45:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:45:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:50:00  profit=     419,046.44  return=   11.26%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:50:00  profit=     193,671.50  return=   17.19%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:50:00  profit=     506,591.25  return=    7.93%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:50:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:50:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 04:55:00  profit=     419,046.44  return=   11.26%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:55:00  profit=     193,671.50  return=   17.19%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:55:00  profit=     506,591.25  return=    7.93%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 04:55:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:55:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:00:00  profit=     419,046.44  return=   11.26%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:00:00  profit=     193,671.50  return=   17.19%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:00:00  profit=     506,591.25  return=    7.93%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:00:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:00:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:05:00  profit=     425,317.90  return=   11.43%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:05:00  profit=     194,904.22  return=   17.30%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:05:00  profit=     513,802.66  return=    8.04%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:05:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:05:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:10:00  profit=     428,326.04  return=   11.51%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:10:00  profit=     195,495.50  return=   17.35%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:10:00  profit=     517,261.65  return=    8.09%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:10:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:10:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:15:00  profit=     428,326.04  return=   11.51%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:15:00  profit=     195,495.50  return=   17.35%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:15:00  profit=     517,261.65  return=    8.09%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:15:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:15:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:20:00  profit=     428,326.04  return=   11.51%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:20:00  profit=     195,495.50  return=   17.35%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:20:00  profit=     517,261.65  return=    8.09%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:20:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:20:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:25:00  profit=     428,326.04  return=   11.51%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:25:00  profit=     195,495.50  return=   17.35%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:25:00  profit=     517,261.65  return=    8.09%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:25:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:25:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:30:00  profit=     428,326.04  return=   11.51%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:30:00  profit=     195,495.50  return=   17.35%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:30:00  profit=     517,261.65  return=    8.09%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:30:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:30:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:35:00  profit=     468,375.24  return=   12.58%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:35:00  profit=     206,461.09  return=   18.31%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:35:00  profit=     573,272.36  return=    8.97%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:35:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:35:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:40:00  profit=     468,375.24  return=   12.58%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:40:00  profit=     206,461.09  return=   18.31%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:40:00  profit=     573,272.36  return=    8.97%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:40:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:40:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:45:00  profit=     462,103.78  return=   12.42%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:45:00  profit=     205,228.37  return=   18.20%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:45:00  profit=     566,060.95  return=    8.85%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:45:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:45:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:50:00  profit=     462,111.57  return=   12.42%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:50:00  profit=     205,236.16  return=   18.20%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:50:00  profit=     566,068.74  return=    8.85%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:50:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:50:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:55:00  profit=     468,522.17  return=   12.59%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 05:55:00  profit=     206,489.97  return=   18.32%  type=Pure Jaspet
# ArbOpp time=2017-01-10 05:55:00  profit=     561,391.51  return=    8.78%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 05:55:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 05:55:00  profit=      35,946.16  return=    1.02%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 05:55:00  profit=     148,782.16  return=    0.85%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 05:55:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:00:00  profit=     468,522.17  return=   12.59%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:00:00  profit=     206,489.97  return=   18.32%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:00:00  profit=     561,391.51  return=    8.78%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:00:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:00:00  profit=      35,946.16  return=    1.02%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 06:00:00  profit=     148,782.16  return=    0.85%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 06:00:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:05:00  profit=     468,522.17  return=   12.59%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:05:00  profit=     206,489.97  return=   18.32%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:05:00  profit=     561,391.51  return=    8.78%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:05:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:05:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:10:00  profit=     473,714.59  return=   12.73%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:10:00  profit=     205,318.24  return=   18.21%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:10:00  profit=     566,491.11  return=    8.86%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:10:00  profit=      74,267.75  return=    1.87%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:10:00  profit=     355,047.66  return=    1.80%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:15:00  profit=     468,750.64  return=   12.59%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:15:00  profit=     206,556.85  return=   18.32%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:15:00  profit=     573,774.76  return=    8.97%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:15:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:15:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:20:00  profit=     471,319.41  return=   12.66%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:20:00  profit=     207,246.32  return=   18.38%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:20:00  profit=     576,599.68  return=    9.02%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:20:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:20:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:25:00  profit=     425,693.30  return=   11.44%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:25:00  profit=     194,999.98  return=   17.30%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:25:00  profit=     514,305.06  return=    8.05%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:25:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:25:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:30:00  profit=     425,693.30  return=   11.44%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:30:00  profit=     194,999.98  return=   17.30%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:30:00  profit=     514,305.06  return=    8.05%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:30:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:30:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:35:00  profit=     425,701.03  return=   11.44%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:35:00  profit=     195,001.50  return=   17.30%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:35:00  profit=     514,313.95  return=    8.05%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:35:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:35:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:40:00  profit=     425,701.03  return=   11.44%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:40:00  profit=     195,001.50  return=   17.30%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:40:00  profit=     514,313.95  return=    8.05%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:40:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:40:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:45:00  profit=     425,701.03  return=   11.44%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:45:00  profit=     195,001.50  return=   17.30%  type=Pure Jaspet
# ArbOpp time=2017-01-10 06:45:00  profit=     514,313.95  return=    8.05%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:45:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:45:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:45:00  profit=   4,912,152.02  return=    5.31%  type=Compressed Gelidus
# ArbOpp time=2017-01-10 06:50:00  profit=     425,701.03  return=   11.44%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:50:00  profit=     514,313.95  return=    8.05%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:50:00  profit=      72,300.68  return=    1.82%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:50:00  profit=     307,547.66  return=    1.56%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 06:50:00  profit=   4,914,035.87  return=    5.31%  type=Compressed Gelidus
# ArbOpp time=2017-01-10 06:55:00  profit=     469,755.94  return=   12.62%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 06:55:00  profit=     580,257.03  return=    9.08%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 06:55:00  profit=      79,382.13  return=    1.99%  type=Fiery Kernite
# ArbOpp time=2017-01-10 06:55:00  profit=       7,925.99  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 06:55:00  profit=     346,277.88  return=    1.76%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 07:00:00  profit=     469,755.94  return=   12.62%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:00:00  profit=     580,257.03  return=    9.08%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:00:00  profit=      79,382.13  return=    1.99%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:00:00  profit=       7,925.99  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:00:00  profit=     346,277.88  return=    1.76%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 07:05:00  profit=     469,755.94  return=   12.62%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:05:00  profit=     580,257.03  return=    9.08%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:05:00  profit=      79,382.13  return=    1.99%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:05:00  profit=       7,925.99  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:05:00  profit=     346,277.88  return=    1.76%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 07:10:00  profit=     469,755.94  return=   12.62%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:10:00  profit=     580,257.03  return=    9.08%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:10:00  profit=      79,382.13  return=    1.99%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:10:00  profit=       7,925.99  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:10:00  profit=     346,277.88  return=    1.76%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 07:15:00  profit=     467,496.49  return=   12.56%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:15:00  profit=     580,257.03  return=    9.08%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:15:00  profit=      78,988.72  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:15:00  profit=       7,457.03  return=    0.37%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:15:00  profit=     268,817.44  return=    1.37%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 07:20:00  profit=     467,496.49  return=   12.56%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:20:00  profit=     580,257.03  return=    9.08%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:20:00  profit=      78,988.72  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:20:00  profit=       7,457.03  return=    0.37%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:20:00  profit=     268,817.44  return=    1.37%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 07:25:00  profit=     467,496.49  return=   12.56%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:25:00  profit=     580,257.03  return=    9.08%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:25:00  profit=      78,988.72  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:25:00  profit=       7,457.03  return=    0.37%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:30:00  profit=     467,496.49  return=   12.56%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:30:00  profit=     580,257.03  return=    9.08%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:30:00  profit=      78,988.72  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:30:00  profit=     184,076.36  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:35:00  profit=     467,496.49  return=   12.56%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:35:00  profit=     580,257.03  return=    9.08%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:35:00  profit=      78,988.72  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:35:00  profit=     184,076.36  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:40:00  profit=     491,117.58  return=   13.19%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:40:00  profit=       9,716.81  return=    0.62%  type=Pure Jaspet
# ArbOpp time=2017-01-10 07:40:00  profit=     624,420.63  return=    9.76%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:40:00  profit=     103,761.21  return=    2.61%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:40:00  profit=     208,659.04  return=    0.43%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:45:00  profit=     491,117.58  return=   13.19%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:45:00  profit=       9,716.81  return=    0.62%  type=Pure Jaspet
# ArbOpp time=2017-01-10 07:45:00  profit=     624,420.63  return=    9.76%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:45:00  profit=       1,386.29  return=    3.64%  type=Luminous Kernite
# ArbOpp time=2017-01-10 07:45:00  profit=     103,761.21  return=    2.61%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:45:00  profit=     208,659.04  return=    0.43%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:50:00  profit=     467,496.49  return=   12.56%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:50:00  profit=     580,257.03  return=    9.08%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:50:00  profit=         251.61  return=    0.66%  type=Luminous Kernite
# ArbOpp time=2017-01-10 07:50:00  profit=      78,988.72  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:50:00  profit=     184,076.36  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:55:00  profit=     467,496.49  return=   12.56%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 07:55:00  profit=     580,257.03  return=    9.08%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 07:55:00  profit=         251.61  return=    0.66%  type=Luminous Kernite
# ArbOpp time=2017-01-10 07:55:00  profit=      78,988.72  return=    1.98%  type=Fiery Kernite
# ArbOpp time=2017-01-10 07:55:00  profit=     184,076.36  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:00:00  profit=     255,484.64  return=    8.28%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 08:00:00  profit=     184,076.36  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:05:00  profit=     255,484.64  return=    8.28%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 08:05:00  profit=     184,076.36  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:10:00  profit=     255,484.64  return=    8.28%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 08:10:00  profit=     184,076.36  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:15:00  profit=     255,484.64  return=    8.28%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 08:15:00  profit=     184,076.36  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:20:00  profit=     255,484.64  return=    8.28%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 08:20:00  profit=     184,076.36  return=    0.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:25:00  profit=     255,607.39  return=    8.28%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 08:25:00  profit=     217,229.04  return=    0.45%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:30:00  profit=     239,195.47  return=    0.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:35:00  profit=     239,195.47  return=    0.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:40:00  profit=     239,195.47  return=    0.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:45:00  profit=     239,195.47  return=    0.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:50:00  profit=     239,195.47  return=    0.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 08:55:00  profit=     239,195.47  return=    0.50%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:00:00  profit=     288,722.34  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:05:00  profit=     288,722.34  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:10:00  profit=     288,722.34  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:15:00  profit=     288,722.34  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:20:00  profit=     288,722.34  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:25:00  profit=     288,722.34  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:30:00  profit=     288,722.34  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:35:00  profit=     288,722.34  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:40:00  profit=     288,722.34  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:45:00  profit=     288,722.34  return=    0.60%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:50:00  profit=     321,672.87  return=    0.67%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 09:55:00  profit=     327,198.32  return=    0.68%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:00:00  profit=     327,198.32  return=    0.68%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:05:00  profit=     155,976.84  return=    0.32%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:10:00  profit=     155,976.84  return=    0.32%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:15:00  profit=     155,976.84  return=    0.32%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:20:00  profit=     155,976.84  return=    0.32%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:25:00  profit=     155,976.84  return=    0.32%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:30:00  profit=     155,976.84  return=    0.32%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:35:00  profit=     155,976.84  return=    0.32%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:40:00  profit=     155,976.84  return=    0.32%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:40:00  profit=       1,287.35  return=    0.99%  type=Gneiss
# ArbOpp time=2017-01-10 10:45:00  profit=     162,919.80  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:45:00  profit=       1,287.35  return=    0.99%  type=Gneiss
# ArbOpp time=2017-01-10 10:50:00  profit=     164,819.80  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:50:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 10:55:00  profit=       5,825.36  return=    0.66%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 10:55:00  profit=     226,648.53  return=    0.47%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 10:55:00  profit=       6,123.27  return=    4.72%  type=Gneiss
# ArbOpp time=2017-01-10 10:55:00  profit=       3,046.78  return=    2.08%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 11:00:00  profit=     188,319.54  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:00:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:05:00  profit=     188,319.54  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:05:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:10:00  profit=     188,319.54  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:10:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:15:00  profit=     188,319.54  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:15:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:20:00  profit=     188,319.54  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:20:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:25:00  profit=     164,819.80  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:25:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:30:00  profit=     164,819.80  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:30:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:35:00  profit=      20,150.50  return=    1.89%  type=Bistot
# ArbOpp time=2017-01-10 11:35:00  profit=       4,608.97  return=    0.50%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 11:35:00  profit=     164,819.80  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:35:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:40:00  profit=      20,150.50  return=    1.89%  type=Bistot
# ArbOpp time=2017-01-10 11:40:00  profit=       4,608.97  return=    0.50%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 11:40:00  profit=     164,819.80  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:40:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:45:00  profit=      20,150.50  return=    1.89%  type=Bistot
# ArbOpp time=2017-01-10 11:45:00  profit=       4,608.97  return=    0.50%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 11:45:00  profit=     164,819.80  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:45:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:50:00  profit=      20,150.50  return=    1.89%  type=Bistot
# ArbOpp time=2017-01-10 11:50:00  profit=       4,608.97  return=    0.50%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 11:50:00  profit=     164,819.80  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:50:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 11:55:00  profit=      20,150.50  return=    1.89%  type=Bistot
# ArbOpp time=2017-01-10 11:55:00  profit=       4,608.97  return=    0.50%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 11:55:00  profit=     164,819.80  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 11:55:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:00:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:00:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:05:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:05:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:10:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:10:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:15:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:15:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:20:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:20:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:25:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:25:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:30:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:30:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:35:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:35:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:40:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:40:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:45:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:45:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:50:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:50:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 12:55:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 12:55:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:00:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:00:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:05:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:05:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:10:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:10:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:15:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:15:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:20:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:20:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:25:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:25:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:30:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:30:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:35:00  profit=     156,473.26  return=    0.33%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:35:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:40:00  profit=     161,944.17  return=    0.34%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:40:00  profit=       1,303.20  return=    1.01%  type=Gneiss
# ArbOpp time=2017-01-10 13:45:00  profit=     166,596.49  return=    0.35%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:45:00  profit=       1,321.69  return=    1.02%  type=Gneiss
# ArbOpp time=2017-01-10 13:50:00  profit=     206,893.14  return=    0.43%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:50:00  profit=       1,323.66  return=    1.02%  type=Gneiss
# ArbOpp time=2017-01-10 13:55:00  profit=     166,772.18  return=    0.35%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 13:55:00  profit=       1,543.00  return=    1.19%  type=Gneiss
# ArbOpp time=2017-01-10 14:00:00  profit=      65,346.00  return=    2.16%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:00:00  profit=   1,170,901.47  return=    2.30%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:00:00  profit=       4,175.01  return=    3.22%  type=Gneiss
# ArbOpp time=2017-01-10 14:00:00  profit=         903.58  return=    0.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:05:00  profit=      64,564.13  return=    2.13%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:05:00  profit=   1,167,233.33  return=    2.30%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:05:00  profit=       4,145.94  return=    3.20%  type=Gneiss
# ArbOpp time=2017-01-10 14:05:00  profit=         871.60  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:10:00  profit=      91,466.17  return=    2.18%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:10:00  profit=   1,167,840.38  return=    2.30%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:10:00  profit=       4,209.37  return=    3.25%  type=Gneiss
# ArbOpp time=2017-01-10 14:10:00  profit=         941.37  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:15:00  profit=      90,859.12  return=    2.16%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:15:00  profit=   1,167,233.33  return=    2.30%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:15:00  profit=       4,145.94  return=    3.20%  type=Gneiss
# ArbOpp time=2017-01-10 14:15:00  profit=         871.60  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:20:00  profit=      90,859.12  return=    2.16%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:20:00  profit=   1,167,233.33  return=    2.30%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:20:00  profit=       4,147.92  return=    3.20%  type=Gneiss
# ArbOpp time=2017-01-10 14:20:00  profit=         873.78  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:25:00  profit=      91,340.77  return=    2.17%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:25:00  profit=   1,173,070.37  return=    2.31%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:25:00  profit=       8,349.65  return=    6.66%  type=Gneiss
# ArbOpp time=2017-01-10 14:25:00  profit=         875.96  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:30:00  profit=      91,340.77  return=    2.17%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:30:00  profit=   1,173,070.37  return=    2.31%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:30:00  profit=       8,349.65  return=    6.66%  type=Gneiss
# ArbOpp time=2017-01-10 14:30:00  profit=         875.96  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:35:00  profit=      93,736.67  return=    2.23%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:35:00  profit=   1,209,063.84  return=    2.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:35:00  profit=       8,378.72  return=    6.68%  type=Gneiss
# ArbOpp time=2017-01-10 14:35:00  profit=         907.93  return=    0.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:40:00  profit=      93,736.67  return=    2.23%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:40:00  profit=   1,267,250.73  return=    2.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:40:00  profit=       8,378.72  return=    6.68%  type=Gneiss
# ArbOpp time=2017-01-10 14:40:00  profit=         907.93  return=    0.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:45:00  profit=      93,736.67  return=    2.23%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:45:00  profit=   1,267,250.73  return=    2.38%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:45:00  profit=       8,378.72  return=    6.68%  type=Gneiss
# ArbOpp time=2017-01-10 14:45:00  profit=         907.93  return=    0.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:50:00  profit=      94,693.80  return=    2.25%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:50:00  profit=   1,276,750.73  return=    2.40%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:50:00  profit=       8,395.24  return=    6.69%  type=Gneiss
# ArbOpp time=2017-01-10 14:50:00  profit=         926.10  return=    0.63%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 14:55:00  profit=      94,693.80  return=    2.25%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:55:00  profit=   1,276,750.73  return=    2.40%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 14:55:00  profit=       8,395.24  return=    6.69%  type=Gneiss
# ArbOpp time=2017-01-10 14:55:00  profit=         926.10  return=    0.63%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:00:00  profit=      94,212.15  return=    2.24%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 15:00:00  profit=   1,270,646.49  return=    2.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 15:00:00  profit=       8,393.26  return=    6.69%  type=Gneiss
# ArbOpp time=2017-01-10 15:00:00  profit=         923.92  return=    0.63%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:05:00  profit=      94,212.15  return=    2.24%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 15:05:00  profit=   1,270,646.49  return=    2.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 15:05:00  profit=       9,742.87  return=    7.77%  type=Gneiss
# ArbOpp time=2017-01-10 15:05:00  profit=       2,409.79  return=    1.65%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:10:00  profit=   1,270,646.49  return=    2.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 15:10:00  profit=       8,393.26  return=    6.69%  type=Gneiss
# ArbOpp time=2017-01-10 15:10:00  profit=         923.92  return=    0.63%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:15:00  profit=   1,285,414.58  return=    2.42%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 15:15:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:15:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:20:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:20:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:25:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:25:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:30:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:30:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:35:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:35:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:40:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:40:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:45:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:45:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:50:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:50:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 15:55:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 15:55:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:00:00  profit=       8,407.79  return=    6.70%  type=Gneiss
# ArbOpp time=2017-01-10 16:00:00  profit=         939.91  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:05:00  profit=     144,566.11  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:05:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:10:00  profit=     144,566.11  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:10:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:15:00  profit=     144,566.11  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:15:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:20:00  profit=     144,566.11  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:20:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:25:00  profit=     144,566.11  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:25:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:30:00  profit=     144,566.11  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:30:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:35:00  profit=     144,566.11  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:35:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:40:00  profit=     144,566.11  return=    6.79%  type=Gneiss
# ArbOpp time=2017-01-10 16:40:00  profit=         942.08  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:45:00  profit=     144,913.98  return=    6.80%  type=Gneiss
# ArbOpp time=2017-01-10 16:45:00  profit=         964.60  return=    0.66%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:50:00  profit=     144,913.98  return=    6.80%  type=Gneiss
# ArbOpp time=2017-01-10 16:50:00  profit=         964.60  return=    0.66%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 16:55:00  profit=     144,319.01  return=    6.77%  type=Gneiss
# ArbOpp time=2017-01-10 16:55:00  profit=         926.10  return=    0.63%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:00:00  profit=     143,577.73  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 17:00:00  profit=         878.13  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:05:00  profit=         669.20  return=    0.02%  type=Compressed Dense Veldspar
# ArbOpp time=2017-01-10 17:05:00  profit=     144,813.20  return=    6.80%  type=Gneiss
# ArbOpp time=2017-01-10 17:05:00  profit=         958.07  return=    0.65%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:10:00  profit=         669.20  return=    0.02%  type=Compressed Dense Veldspar
# ArbOpp time=2017-01-10 17:10:00  profit=     166,042.54  return=    7.79%  type=Gneiss
# ArbOpp time=2017-01-10 17:10:00  profit=       2,331.96  return=    1.59%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:15:00  profit=         669.20  return=    0.02%  type=Compressed Dense Veldspar
# ArbOpp time=2017-01-10 17:15:00  profit=     166,042.54  return=    7.79%  type=Gneiss
# ArbOpp time=2017-01-10 17:15:00  profit=       2,331.96  return=    1.59%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:20:00  profit=     166,536.73  return=    7.81%  type=Gneiss
# ArbOpp time=2017-01-10 17:20:00  profit=       2,363.94  return=    1.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:25:00  profit=     166,536.73  return=    7.81%  type=Gneiss
# ArbOpp time=2017-01-10 17:25:00  profit=       2,363.94  return=    1.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:30:00  profit=     166,042.54  return=    7.79%  type=Gneiss
# ArbOpp time=2017-01-10 17:30:00  profit=       2,331.96  return=    1.59%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:35:00  profit=     166,042.54  return=    7.79%  type=Gneiss
# ArbOpp time=2017-01-10 17:35:00  profit=       2,331.96  return=    1.59%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:40:00  profit=     209,439.04  return=    9.82%  type=Gneiss
# ArbOpp time=2017-01-10 17:40:00  profit=       5,140.13  return=    3.51%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:45:00  profit=     143,611.32  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 17:45:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:50:00  profit=     143,611.32  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 17:50:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:55:00  profit=     143,611.32  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 17:55:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:00:00  profit=     143,611.32  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 18:00:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:05:00  profit=     143,611.32  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 18:05:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:10:00  profit=     143,611.32  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 18:10:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:15:00  profit=     143,611.32  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 18:15:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:20:00  profit=     143,611.32  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 18:20:00  profit=         880.31  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:25:00  profit=     143,577.73  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 18:25:00  profit=         878.13  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:30:00  profit=     143,577.73  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 18:30:00  profit=         878.13  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:35:00  profit=     219,670.60  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 18:35:00  profit=         878.13  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:40:00  profit=     219,670.60  return=    6.74%  type=Gneiss
# ArbOpp time=2017-01-10 18:40:00  profit=         878.13  return=    0.60%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:45:00  profit=      91,391.13  return=   10.12%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 18:45:00  profit=     220,907.32  return=    6.78%  type=Gneiss
# ArbOpp time=2017-01-10 18:45:00  profit=         930.46  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:50:00  profit=     220,907.32  return=    6.78%  type=Gneiss
# ArbOpp time=2017-01-10 18:50:00  profit=         930.46  return=    0.64%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 18:55:00  profit=     222,144.05  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 18:55:00  profit=         982.78  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:00:00  profit=     222,144.05  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 19:00:00  profit=         982.78  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:05:00  profit=     222,144.05  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 19:05:00  profit=         982.78  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:10:00  profit=     222,144.05  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 19:10:00  profit=         982.78  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:15:00  profit=     222,968.54  return=    6.84%  type=Gneiss
# ArbOpp time=2017-01-10 19:15:00  profit=       1,017.67  return=    0.70%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:20:00  profit=       2,550.28  return=    4.26%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 19:20:00  profit=      12,917.87  return=    1.32%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 19:20:00  profit=     356,541.10  return=   10.49%  type=Gneiss
# ArbOpp time=2017-01-10 19:20:00  profit=       6,556.93  return=    4.48%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:25:00  profit=       3,465.07  return=    0.36%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 19:25:00  profit=     325,783.67  return=    9.59%  type=Gneiss
# ArbOpp time=2017-01-10 19:25:00  profit=       5,303.27  return=    3.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:30:00  profit=     223,259.26  return=    6.85%  type=Gneiss
# ArbOpp time=2017-01-10 19:30:00  profit=       1,029.98  return=    0.70%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:35:00  profit=     222,022.53  return=    6.81%  type=Gneiss
# ArbOpp time=2017-01-10 19:35:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:40:00  profit=     222,022.53  return=    6.81%  type=Gneiss
# ArbOpp time=2017-01-10 19:40:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:45:00  profit=     222,022.53  return=    6.81%  type=Gneiss
# ArbOpp time=2017-01-10 19:45:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:50:00  profit=     222,022.53  return=    6.81%  type=Gneiss
# ArbOpp time=2017-01-10 19:50:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 19:55:00  profit=     222,434.77  return=    6.83%  type=Gneiss
# ArbOpp time=2017-01-10 19:55:00  profit=         995.10  return=    0.68%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:00:00  profit=     222,434.77  return=    6.83%  type=Gneiss
# ArbOpp time=2017-01-10 20:00:00  profit=         995.10  return=    0.68%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:05:00  profit=     243,230.42  return=    3.25%  type=Vitric Hedbergite
# ArbOpp time=2017-01-10 20:05:00  profit=     443,163.43  return=    8.49%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 20:05:00  profit=     222,966.81  return=    6.84%  type=Gneiss
# ArbOpp time=2017-01-10 20:05:00  profit=       1,017.61  return=    0.70%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:10:00  profit=     443,856.55  return=    8.50%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 20:10:00  profit=     377,400.90  return=    6.84%  type=Gneiss
# ArbOpp time=2017-01-10 20:10:00  profit=       1,017.61  return=    0.70%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:15:00  profit=     470,749.61  return=    9.01%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 20:15:00  profit=     435,305.19  return=    7.89%  type=Gneiss
# ArbOpp time=2017-01-10 20:15:00  profit=       2,465.30  return=    1.68%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:20:00  profit=     107,842.23  return=    2.29%  type=Viscous Pyroxeres
# ArbOpp time=2017-01-10 20:20:00  profit=     435,305.19  return=    7.89%  type=Gneiss
# ArbOpp time=2017-01-10 20:20:00  profit=       2,465.30  return=    1.68%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:25:00  profit=      63,020.16  return=    1.34%  type=Viscous Pyroxeres
# ArbOpp time=2017-01-10 20:25:00  profit=     376,063.72  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:25:00  profit=         984.18  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:30:00  profit=      63,020.16  return=    1.34%  type=Viscous Pyroxeres
# ArbOpp time=2017-01-10 20:30:00  profit=     375,802.89  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:30:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:35:00  profit=     375,802.89  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:35:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:40:00  profit=     375,802.89  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:40:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:45:00  profit=     375,802.89  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:45:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:50:00  profit=     375,802.89  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:50:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 20:55:00  profit=     375,802.89  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 20:55:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 21:00:00  profit=     375,802.89  return=    6.82%  type=Gneiss
# ArbOpp time=2017-01-10 21:00:00  profit=         977.65  return=    0.67%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 21:05:00  profit=     251,622.61  return=    4.57%  type=Gneiss
# ArbOpp time=2017-01-10 21:10:00  profit=     251,622.61  return=    4.57%  type=Gneiss
# ArbOpp time=2017-01-10 21:15:00  profit=     303,990.91  return=    4.58%  type=Gneiss
# ArbOpp time=2017-01-10 21:20:00  profit=       2,566.22  return=    4.29%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 21:20:00  profit=      42,795.55  return=    2.56%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 21:20:00  profit=      19,858.26  return=    2.02%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 21:20:00  profit=     130,689.38  return=    2.77%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 21:20:00  profit=     776,166.16  return=   11.66%  type=Gneiss
# ArbOpp time=2017-01-10 21:20:00  profit=       7,673.90  return=    5.24%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 21:25:00  profit=       2,566.22  return=    4.29%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 21:25:00  profit=      42,795.55  return=    2.56%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 21:25:00  profit=      19,858.26  return=    2.02%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 21:25:00  profit=     130,689.38  return=    2.77%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 21:25:00  profit=     776,166.16  return=   11.66%  type=Gneiss
# ArbOpp time=2017-01-10 21:25:00  profit=       7,673.90  return=    5.24%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 21:30:00  profit=     303,990.91  return=    4.58%  type=Gneiss
# ArbOpp time=2017-01-10 21:35:00  profit=     303,990.91  return=    4.58%  type=Gneiss
# ArbOpp time=2017-01-10 21:40:00  profit=     303,990.91  return=    4.58%  type=Gneiss
# ArbOpp time=2017-01-10 21:45:00  profit=     303,990.91  return=    4.58%  type=Gneiss
# ArbOpp time=2017-01-10 21:50:00  profit=     298,370.10  return=    4.58%  type=Gneiss
# ArbOpp time=2017-01-10 21:55:00  profit=     298,370.10  return=    4.58%  type=Gneiss
# ArbOpp time=2017-01-10 22:00:00  profit=     298,370.10  return=    4.58%  type=Gneiss
# ArbOpp time=2017-01-10 22:05:00  profit=     307,870.10  return=    4.73%  type=Gneiss
# ArbOpp time=2017-01-10 22:10:00  profit=     307,870.10  return=    4.73%  type=Gneiss
# ArbOpp time=2017-01-10 22:15:00  profit=     318,528.03  return=    4.89%  type=Gneiss
# ArbOpp time=2017-01-10 22:20:00  profit=     321,654.06  return=    4.94%  type=Gneiss
# ArbOpp time=2017-01-10 22:25:00  profit=     300,303.87  return=    4.61%  type=Gneiss
# ArbOpp time=2017-01-10 22:30:00  profit=     300,303.87  return=    4.61%  type=Gneiss
# ArbOpp time=2017-01-10 22:35:00  profit=      36,456.97  return=    6.69%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 22:35:00  profit=     299,701.01  return=    4.60%  type=Gneiss
# ArbOpp time=2017-01-10 22:40:00  profit=      45,100.55  return=    8.27%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 22:40:00  profit=     299,803.77  return=    4.61%  type=Gneiss
# ArbOpp time=2017-01-10 22:45:00  profit=      45,115.08  return=    8.27%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 22:45:00  profit=     301,114.77  return=    4.63%  type=Gneiss
# ArbOpp time=2017-01-10 22:50:00  profit=      45,115.08  return=    8.27%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 22:50:00  profit=     300,166.70  return=    4.61%  type=Gneiss
# ArbOpp time=2017-01-10 22:55:00  profit=      45,246.94  return=    8.30%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 22:55:00  profit=     301,025.28  return=    4.62%  type=Gneiss
# ArbOpp time=2017-01-10 23:00:00  profit=      45,335.48  return=    8.31%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 23:00:00  profit=     301,883.85  return=    4.64%  type=Gneiss
# ArbOpp time=2017-01-10 23:05:00  profit=      45,335.48  return=    8.31%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 23:05:00  profit=     301,883.85  return=    4.64%  type=Gneiss
# ArbOpp time=2017-01-10 23:10:00  profit=      45,335.48  return=    8.31%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 23:10:00  profit=     301,883.85  return=    4.64%  type=Gneiss
# ArbOpp time=2017-01-10 23:15:00  profit=      45,335.48  return=    8.31%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 23:15:00  profit=     303,652.98  return=    4.67%  type=Gneiss
# ArbOpp time=2017-01-10 23:20:00  profit=      45,335.48  return=    8.31%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 23:20:00  profit=     303,652.98  return=    4.67%  type=Gneiss
# ArbOpp time=2017-01-10 23:25:00  profit=      45,352.58  return=    8.32%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 23:25:00  profit=     303,652.98  return=    4.67%  type=Gneiss
# ArbOpp time=2017-01-10 23:30:00  profit=     303,652.98  return=    4.67%  type=Gneiss
# ArbOpp time=2017-01-10 23:35:00  profit=     304,601.04  return=    4.68%  type=Gneiss
# ArbOpp time=2017-01-10 23:40:00  profit=     301,886.02  return=    4.64%  type=Gneiss
# ArbOpp time=2017-01-10 23:45:00  profit=     302,710.50  return=    4.65%  type=Gneiss
# ArbOpp time=2017-01-10 23:50:00  profit=     303,018.76  return=    4.66%  type=Gneiss
# ArbOpp time=2017-01-10 23:55:00  profit=     303,018.76  return=    4.66%  type=Gneiss
# Total opportunities: 669

# %%
# Some of the opportunities for this day look very promising.  In preparation for a backtest over
# a longer date range, we'd like to determine the total value of all the opportunities for a
# given day.  Notice, however, that the same opportunity is often available over many consecutive 
# snapshots.  We'd like to count each distinct opportunity exactly once to avoid skewing our results 
# with double counting.  A simple way to do this is to collapse all opportunities for the same type 
# over consecutive snaphots into a single opportunity.  For simplicity, we'll use the first appearance 
# of an opportunity as the representative for consecutive instances of the same opportunity.
# This isn't perfect, but is a reasonable approximation that will make it easier to estimate the
# total opportunity value of a given day.
def clean_opportunities(opps):
    new_opps = []
    stamp_map = {}
    types = set([x['type'] for x in opps])
    # Flatten opportunites for each type
    for next_type in types:
        stamp_list = []
        last = None
        for i in [x['time'] for x in opps if x['type'] == next_type]:
            if last is None:
                # First opportunity
                stamp_list.append(i)
            elif i - last > datetime.timedelta(minutes=5):
                # Start of new run
                stamp_list.append(i)
            last = i
        stamp_map[next_type] = stamp_list
    # Rebuild opportunities by only selecting opportunities in
    # the flattened lists.
    for opp in opps:
        type = opp['type']
        if opp['time'] in stamp_map[type]:
            new_opps.append(opp)
    # Return the new opportunity list
    return new_opps

# %%
cleaned_full_opps = clean_opportunities(full_opportunities)
display_opportunities(cleaned_full_opps)
# Out:
# ArbOpp time=2017-01-10 00:50:00  profit=  17,105,026.82  return=    1.98%  type=Compressed Triclinic Bistot
# ArbOpp time=2017-01-10 00:50:00  profit=  14,630,218.82  return=    0.29%  type=Compressed Bright Spodumain
# ArbOpp time=2017-01-10 01:05:00  profit=          21.02  return=    0.00%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 02:10:00  profit=         360.84  return=    0.04%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 02:55:00  profit=   8,845,325.06  return=    0.61%  type=Compressed Monoclinic Bistot
# ArbOpp time=2017-01-10 03:15:00  profit=      19,352.71  return=    0.96%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 03:30:00  profit=     203,293.25  return=   31.99%  type=Vivid Hemorphite
# ArbOpp time=2017-01-10 04:05:00  profit=     193,516.46  return=   17.17%  type=Pure Jaspet
# ArbOpp time=2017-01-10 04:05:00  profit=      71,710.56  return=    1.80%  type=Fiery Kernite
# ArbOpp time=2017-01-10 04:10:00  profit=     359,443.15  return=    3.12%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 05:55:00  profit=      35,946.16  return=    1.02%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 05:55:00  profit=     148,782.16  return=    0.85%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 06:45:00  profit=   4,912,152.02  return=    5.31%  type=Compressed Gelidus
# ArbOpp time=2017-01-10 06:55:00  profit=       7,925.99  return=    0.39%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 07:40:00  profit=       9,716.81  return=    0.62%  type=Pure Jaspet
# ArbOpp time=2017-01-10 07:45:00  profit=       1,386.29  return=    3.64%  type=Luminous Kernite
# ArbOpp time=2017-01-10 10:40:00  profit=       1,287.35  return=    0.99%  type=Gneiss
# ArbOpp time=2017-01-10 10:55:00  profit=       5,825.36  return=    0.66%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 10:55:00  profit=       3,046.78  return=    2.08%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 11:35:00  profit=      20,150.50  return=    1.89%  type=Bistot
# ArbOpp time=2017-01-10 11:35:00  profit=       4,608.97  return=    0.50%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:00:00  profit=      65,346.00  return=    2.16%  type=Azure Plagioclase
# ArbOpp time=2017-01-10 14:00:00  profit=         903.58  return=    0.62%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 17:05:00  profit=         669.20  return=    0.02%  type=Compressed Dense Veldspar
# ArbOpp time=2017-01-10 18:45:00  profit=      91,391.13  return=   10.12%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 19:20:00  profit=       2,550.28  return=    4.26%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 19:20:00  profit=      12,917.87  return=    1.32%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 20:05:00  profit=     243,230.42  return=    3.25%  type=Vitric Hedbergite
# ArbOpp time=2017-01-10 20:05:00  profit=     443,163.43  return=    8.49%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 20:20:00  profit=     107,842.23  return=    2.29%  type=Viscous Pyroxeres
# ArbOpp time=2017-01-10 21:20:00  profit=       2,566.22  return=    4.29%  type=Glazed Hedbergite
# ArbOpp time=2017-01-10 21:20:00  profit=      42,795.55  return=    2.56%  type=Pristine Jaspet
# ArbOpp time=2017-01-10 21:20:00  profit=      19,858.26  return=    2.02%  type=Rich Plagioclase
# ArbOpp time=2017-01-10 21:20:00  profit=     130,689.38  return=    2.77%  type=Concentrated Veldspar
# ArbOpp time=2017-01-10 21:20:00  profit=       7,673.90  return=    5.24%  type=Prismatic Gneiss
# ArbOpp time=2017-01-10 22:35:00  profit=      36,456.97  return=    6.69%  type=Glazed Hedbergite
# Total opportunities: 36

# %%
# Finally, we can summarize the performance of our sample day
total_profit = np.sum([x['profit'] for x in cleaned_full_opps])
total_cost = np.sum([x['cost'] for x in cleaned_full_opps])
total_return = total_profit / total_cost
print("Total opportunity profit: %s ISK" % "{:,.2f}".format(total_profit))
print("Total opportunity retrun: %s%% ISK" % "{:,.2f}".format(total_return * 100))
# Out:
# Total opportunity profit: 47,787,151.48 ISK
# Total opportunity retrun: 0.64% ISK

# %% [markdown]
# The sample day is reasonably profitable if you manage to catch all the opportunities as they occur.
# It's also interesting to note that the bulk of the profit for the day is captured in just four
# large opportunities.  The remaining opportunities are much smaller.
#
# Our next task is to determine whether arbitrage opportunities are a frequent occurrence,
# or whether we were fortunate to select a profitable day.  We'll take this up in the next
# example.
